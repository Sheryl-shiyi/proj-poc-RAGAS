# %% [markdown]
# # RAGAS Evaluation: answer_similarity + answer_correctness
#
# Loads cached eval_data (from `query_rag_system.ipynb`) and runs answer quality metrics.
# Metrics are submitted as separate jobs for fault isolation — `answer_similarity` (fast, embedding-only) runs first.
#
# **Prerequisites:**
# - `eval_data_health_wallet.json` generated by `query_rag_system.ipynb`
#
# **Metrics:**
# - `answer_similarity` — Semantic similarity between RAG answer and ground truth (embedding cosine)
# - `answer_correctness` — Factual correctness of answer vs ground truth (F1 + semantic similarity)
#
# **See also:** `ragas_eval_context_metrics.ipynb` for context_precision + context_recall.

# %% [markdown]
# ## Step 0: Setup and Dependencies

# %%
# !pip install -q llama-stack-client==0.4.2 rich pandas

# %%
import json
import time
from datetime import datetime

import pandas as pd
from llama_stack_client import LlamaStackClient
from rich.pretty import pprint


def compute_aggregated(score_result):
    """Compute mean from per-question scores, skipping None/NaN entries.
    Falls back to RAGAS aggregated_results if available."""
    agg = score_result.aggregated_results
    if agg is not None and not (isinstance(agg, dict) and None in agg.values()):
        if isinstance(agg, dict):
            vals = [v for v in agg.values() if v is not None]
            return vals[0] if len(vals) == 1 else agg
        return agg
    scores = []
    for row in score_result.score_rows:
        s = row.get("score")
        if s is not None and str(s) != "nan":
            scores.append(float(s))
    return round(sum(scores) / len(scores), 6) if scores else None

# %%
# --- Configuration ---
RAGAS_URL = "http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321"
PROVIDER_ID_INLINE = "trustyai_ragas_inline"

# %%
ragas_client = LlamaStackClient(base_url=RAGAS_URL)

print("RAGAS system models:")
ragas_models = ragas_client.models.list()
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', '?')
    mtype = getattr(m, 'model_type', '?')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    print(f"  {mid} ({mtype})")

print("\nRAGAS eval providers:")
providers = ragas_client.providers.list()
eval_providers = [p for p in providers if p.api == "eval"]
pprint(eval_providers)
# Out:
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/models "HTTP/1.1 200 OK"
# RAGAS system models:
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/providers "HTTP/1.1 200 OK"
#   vllm-embedding/qwen3-4b-embedding (embedding)
#   vllm-inference/Gemma-3-27B-BF16-Distributed (llm)
#
# RAGAS eval providers:
# [
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'use_k8s': True,
# │   │   │   'base_url': 'http://gemma-3-27b-bf16-distributed-predictor.vszp.svc.cluster.local:8080/v1'
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_lmeval',
# │   │   provider_type='remote::trustyai_lmeval'
# │   ),
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'embedding_model': 'vllm-embedding/qwen3-4b-embedding',
# │   │   │   'ragas_config': {'raise_exceptions': False}
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_ragas_inline',
# │   │   provider_type='inline::trustyai_ragas'
# │   )
# ]

# %% [markdown]
# ## Load Eval Data

# %%
with open("eval_data_health_wallet.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)
print(f"Loaded {len(eval_data)} evaluation entries")
# Out:
# Loaded 182 evaluation entries

# %% [markdown]
# ## Step 4: Run RAGAS Evaluation

# %%
SCORING_FUNCTIONS = [
    "answer_similarity",
    "answer_correctness",
]

# answer_similarity.name returns "semantic_similarity" in ragas 0.3.0
METRIC_ALIASES = {"answer_similarity": "semantic_similarity"}

# Find the LLM model ID in RAGAS system
ragas_llm_model = None
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', None)
    mtype = getattr(m, 'model_type', '')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    if mtype == 'llm':
        ragas_llm_model = mid
        break

assert ragas_llm_model, "No LLM model found in RAGAS system!"
print(f"Using LLM for evaluation: {ragas_llm_model}")


def _resolve_metric_key(scores_dict, metric_name):
    """Find the actual key in scores_dict, checking aliases."""
    if metric_name in scores_dict:
        return metric_name
    alias = METRIC_ALIASES.get(metric_name)
    if alias and alias in scores_dict:
        return alias
    return None


def run_ragas_metric(metric_names, eval_data, label=None):
    """Register dataset + benchmark, run eval, return results or None on failure."""
    label = label or "_".join(metric_names)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    ds_id = f"hw_{label}_{ts}"
    bm_id = f"hw_bench_{label}_{ts}"

    ragas_client.beta.datasets.register(
        dataset_id=ds_id,
        purpose="eval/question-answer",
        source={"type": "rows", "rows": eval_data},
        metadata={"provider_id": "localfs"},
    )
    ragas_client.alpha.benchmarks.register(
        benchmark_id=bm_id,
        dataset_id=ds_id,
        scoring_functions=metric_names,
        provider_id=PROVIDER_ID_INLINE,
    )

    job = ragas_client.alpha.eval.run_eval(
        benchmark_id=bm_id,
        benchmark_config={
            "eval_candidate": {
                "type": "model",
                "model": ragas_llm_model,
                "sampling_params": {"temperature": 0.1, "max_tokens": 1500},
            },
            "scoring_params": {},
        },
    )
    print(f"[{label}] Job {job.job_id} submitted. Metrics: {metric_names}")

    start = time.time()
    while True:
        st = ragas_client.alpha.eval.jobs.status(benchmark_id=bm_id, job_id=job.job_id)
        elapsed = time.time() - start
        print(f"  [{elapsed:.0f}s] {st.status}")
        if st.status in ("completed", "failed"):
            break
        time.sleep(15)

    if st.status == "failed":
        print(f"  FAILED after {elapsed:.0f}s")
        return None

    results = ragas_client.alpha.eval.jobs.retrieve(benchmark_id=bm_id, job_id=job.job_id)
    print(f"  Completed in {elapsed:.0f}s")
    print(f"  Returned score keys: {list(results.scores.keys())}")
    for mn in metric_names:
        key = _resolve_metric_key(results.scores, mn)
        if key:
            agg = compute_aggregated(results.scores[key])
            print(f"  {mn}: {agg}")
        else:
            print(f"  {mn}: NOT FOUND in results")
    return results
# Out:
# Using LLM for evaluation: vllm-inference/Gemma-3-27B-BF16-Distributed

# %%
# Job 1: answer_similarity (embedding-only, fast)
results_sim = run_ragas_metric(["answer_similarity"], eval_data, label="similarity")
# Out:
# /tmp/ipykernel_1447/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_1447/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_143152/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_143152/jobs/2 "HTTP/1.1 200 OK"
# [similarity] Job 2 submitted. Metrics: ['answer_similarity']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_143152/jobs/2 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_143152/jobs/2 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_143152/jobs/2/result "HTTP/1.1 200 OK"
#   [31s] completed
#   Completed in 31s
#   Returned score keys: ['semantic_similarity']
#   answer_similarity: 0.8311921072830002

# %%
# Job 2: answer_correctness (LLM-based, slower)
results_corr = run_ragas_metric(["answer_correctness"], eval_data, label="correctness")
# Out:
# /tmp/ipykernel_1447/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_1447/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
# [correctness] Job 3 submitted. Metrics: ['answer_correctness']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [30s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [45s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [60s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [75s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [90s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [105s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [120s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [135s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [150s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [165s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [180s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [195s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [210s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [225s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [240s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [255s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [270s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [285s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [300s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [315s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [330s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [345s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [360s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [375s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [390s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [405s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [420s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [435s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [451s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [466s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [481s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [496s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [511s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [526s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [541s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [556s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [571s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [586s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [601s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [616s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [631s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [646s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [661s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [676s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [691s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [706s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [721s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [736s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [751s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [766s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [781s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [796s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [811s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [826s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [841s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [856s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [871s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [886s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [901s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [916s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [931s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [946s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [961s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [976s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [991s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1006s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1021s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1036s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1051s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1066s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1081s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1096s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1111s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1126s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1141s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1156s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1171s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1186s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1201s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1216s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1231s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1246s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1261s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1276s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1291s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1306s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1321s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1336s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1351s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1366s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1382s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1397s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1412s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1427s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1442s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1457s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1472s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1487s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1502s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1517s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1532s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1547s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1562s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1577s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1592s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1607s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1622s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1637s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1652s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1667s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1682s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1697s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1712s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1727s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1742s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1757s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1772s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1787s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1802s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1817s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1832s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1847s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1862s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1877s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1892s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1907s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1922s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1937s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1952s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1967s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1982s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [1997s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2012s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2027s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2042s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2057s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2072s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2087s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2102s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2117s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2132s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2147s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2162s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2177s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2192s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2207s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2222s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2237s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2252s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2267s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2282s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2297s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2312s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2327s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2342s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2358s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2373s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2388s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2403s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2418s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2433s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2448s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2463s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2478s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2493s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2508s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2523s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2538s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2553s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2568s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2583s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2598s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2613s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2628s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2643s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2658s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2673s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2688s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2703s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2718s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2733s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2748s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2763s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2778s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2793s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2808s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2823s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2838s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2853s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2868s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2883s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2898s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2913s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2928s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2943s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2958s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2973s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [2988s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3003s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3018s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3033s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3048s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3063s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3078s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3093s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3108s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3123s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3138s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3153s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3168s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3183s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3198s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3213s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3228s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3243s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3258s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3273s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3289s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3304s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3319s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3334s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [3349s] in_progress
# ...
#   [8289s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8304s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8319s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8334s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8349s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8364s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8379s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8394s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8409s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8424s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8439s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8454s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8469s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8484s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8499s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8514s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8529s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8544s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8559s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8574s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8589s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8604s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8619s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8634s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8649s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8664s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8679s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8694s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8709s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8724s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8739s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8754s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8769s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8784s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8799s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8815s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8830s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8845s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8860s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8875s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8890s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8905s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8920s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8935s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8950s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8965s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8980s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [8995s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9010s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9025s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9040s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9055s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9070s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9085s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9100s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9115s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9130s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9145s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9160s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9175s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9190s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9205s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9220s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9235s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9250s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9265s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9280s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9295s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9310s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9325s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9340s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9355s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9370s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
#   [9385s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_143223/jobs/3/result "HTTP/1.1 200 OK"
#   [9400s] completed
#   Completed in 9400s
#   Returned score keys: ['answer_correctness']
#   answer_correctness: 0.579982

# %% [markdown]
# ## Step 5: Results Analysis

# %%
# Merge scores from both jobs, normalizing metric names
all_scores = {}
ref_results = None
for r in [results_sim, results_corr]:
    if r is not None:
        ref_results = ref_results or r
        for mn, sr in r.scores.items():
            all_scores[mn] = sr

# Normalize: map aliases back to canonical names (e.g. semantic_similarity -> answer_similarity)
reverse_aliases = {v: k for k, v in METRIC_ALIASES.items()}
for alias, canonical in reverse_aliases.items():
    if alias in all_scores and canonical not in all_scores:
        all_scores[canonical] = all_scores.pop(alias)

# Build results DataFrame
rows = []
if ref_results:
    for i, gen in enumerate(ref_results.generations):
        row = {"question": gen["user_input"][:80]}
        for metric in SCORING_FUNCTIONS:
            if metric in all_scores:
                score_rows = all_scores[metric].score_rows
                if i < len(score_rows):
                    score = score_rows[i].get("score", None)
                    if score is not None and str(score) != "nan":
                        row[metric] = score
                    else:
                        row[metric] = None
        rows.append(row)

df = pd.DataFrame(rows)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Summary
print("=" * 80)
print("RAGAS EVALUATION RESULTS - Health Wallet RAG")
print("=" * 80)
print(f"\nEval Data:    {len(eval_data)} questions")
print(f"Timestamp:    {timestamp}")
print()

print("AGGREGATED SCORES:")
print("-" * 40)
for metric in SCORING_FUNCTIONS:
    if metric in all_scores:
        sr = all_scores[metric]
        agg = compute_aggregated(sr)
        scored = sum(1 for r in sr.score_rows if r.get("score") is not None and str(r.get("score")) != "nan")
        skipped = len(sr.score_rows) - scored
        suffix = f" ({skipped} skipped)" if skipped > 0 else ""
        print(f"  {metric:25s}: {agg}{suffix}")
    else:
        print(f"  {metric:25s}: FAILED")
print()
# Out:
# ================================================================================
# RAGAS EVALUATION RESULTS - Health Wallet RAG
# ================================================================================
#
# Eval Data:    182 questions
# Timestamp:    20260509_170904
#
# AGGREGATED SCORES:
# ----------------------------------------
#   answer_similarity        : 0.8311921072830002
#   answer_correctness       : 0.579982 (1 skipped)

# %%
# Per-question breakdown
print("PER-QUESTION SCORES:")
print("-" * 80)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', 200)
print(df.to_string(index=False))
# Out:
# PER-QUESTION SCORES:
# --------------------------------------------------------------------------------
#                                                                          question  answer_similarity  answer_correctness
#                                     Kde nájdem Peňaženku zdravia? Je spoplatnená?           0.931591            0.706582
#                          Prečo je Peňaženka zdravia viazaná na mobilnú aplikáciu?           0.871933            0.617983
# Na čerpanie príspevkov z Peňaženky zdravia musím mať mobilnú aplikáciu,\nalebo mi           0.889064            0.650837
# Ak som sa opäť vrátil do VšZP, môžem pre Peňaženku zdravia využívať svoje\nstaré            0.742033            0.785596
#       Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku\nzdravia?           0.658843            0.229709
# Aktualizácia mobilnej aplikácie prebehne automaticky, alebo si novú verziu\nmusím           0.791732            0.531335
# Máte kontakt na podporu pre klientov? Mám problémy s inštaláciou mobilnej\napliká           0.765788            0.691412
#  Prečo je potrebná aktivácia mobilnej aplikácie? Nie je to zbytočná strata\nčasu?           0.796228            0.649484
#               Ak mám nový telefón, musím si opätovne aktivovať mobilnú aplikáciu?           0.883159            0.720854
# Ak si nanovo zaktivujem aplikáciu, musím si opätovne vytvoriť aj skupinu v\nPeňaž           0.771021            0.755428
#                                           Budú sa finančné príspevky časom meniť?           0.717000            0.379231
# Prečo musím potvrdiť nejaké súhlasy, ak chcem čerpať príspevky z\nPeňaženky zdrav           0.833554            0.489689
# Na čo slúži e-mailová adresa? Je to povinný údaj? Budem dostávať z\nmobilnej apli           0.672254            0.398738
# Kde nájdem presný zoznam finančných príspevkov, ktoré môžem čerpať z\nPeňaženky z           0.892397            0.822982
# Môžem čerpať finančné príspevky z Peňaženky zdravia aj bez vytvárania\nskupiny, t           0.880392            0.396632
#                               Aký limit finančných prostriedkov mám k dispozícii?           0.893097            0.723178
#                      Kto môže čerpať finančné príspevky v Peňaženke zdravia MINI?           0.894763            0.423662
#          Mám pozvánku do skupiny. Môžem v tomto štádiu čerpať finančné príspevky?           0.904286            0.425945
#  Začal som vytvárať skupinu, sme zatiaľ 2 a neviem, kedy sa nám podarí vytvoriť s           0.940041            0.609927
#                 Môže finančné príspevky z Peňaženky zdravia MINI čerpať aj dieťa?           0.934445            0.514919
#  Aký je postup čerpania finančných príspevkov z Peňaženky zdravia MINI pre dieťa?           0.834636            0.617642
#  Môžem ako dospelý v Peňaženke zdravia MINI konať aj za dieťa, ktoré mi bolo zver           0.795388            0.948837
#  Môže požiadať o čerpanie finančných príspevkov z Peňaženky zdravia MINI aj osoba           0.733133            0.633293
#  Môžem požiadať o finančný príspevok ako fyzická osoba, ak som ako FO – podnikate           0.747821            0.411837
#  Po príchode zo zahraničia sa poistím vo VšZP. Môžem požiadať o finančný príspevo           0.924233            0.692515
#  Preplatíte mi žiadosť o finančný príspevok v prípade, že odídem do zahraničia a            0.820168            0.538401
#  Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís           0.876442            0.219089
#                                                Ako požiadam o finančný príspevok?           0.832304            0.384273
#                                                 Do akej doby musím podať žiadosť?           0.913030            0.415873
#                  Čo potrebujem k podaniu žiadosti? Kde a ako mám žiadosť vyplniť?           0.908458            0.577119
#                                    Sú obmedzenia pri podávaní prílohy k žiadosti?           0.761107            0.421077
#                                                 Ako zistím, kto je zmluvný lekár?           0.928543            0.875007
#  Môžem si podať žiadosť o finančný príspevok aj v prípade, že som navštívil súkro           0.850539            0.528484
#                              Musím mať absolvované všetky preventívne prehliadky?           0.861416            0.695248
#                Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára?           0.826682            0.432061
#  Môže získať finančný príspevok na prenatálne testovanie aj žena vo veku 30 rokov           0.804257            0.482261
#  Aká je maximálna výška finančného príspevku, ktorú môže žena získať na moderné c           0.936973            0.984114
#  Je potrebný predchádzajúci súhlas poisťovne na získanie finančného príspevku na            0.771902            0.568102
#  Je potrebný predchádzajúci súhlas poisťovne na získanie príspevku na 4.cyklus as           0.814971            0.612888
#  Dá sa získať finančný príspevok aj na 4. cyklus asistovanej reprodukcie IVF mimo           0.869473            0.717397
#  Má nárok na získanie finančný príspevku na 4.cyklus asistovanej reprodukcie IVF            0.866271            0.816425
#  Je možné v rámci finančného príspevku 100 €/ročne na doplatky za glukózové senzo           0.900441            0.787597
#  Prečo je stanovená podmienka uplatnenia finančného príspevku na glukózové senzor           0.890992            0.544181
#  Je možné získať finančný príspevok aj na doplatky za glukózové senzory pre dieťa           0.556091            0.388787
#                              Pre akú skupinu diabetikov platí finančný príspevok?           0.902696            0.600719
#     Za akých podmienok môžem zmeniť Peňaženku zdravia MINI na MAXI alebo\nnaopak?           0.941702            0.592564
#     Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho\nroka?           0.379246            0.344740
#  Čo sa stane s mojimi finančnými prostriedkami, ktoré som čerpal pred zmenou typu           0.929949            0.607527

# %%
# Identify weak spots
print("\nDIAGNOSTICS:")
print("=" * 60)

for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[df[metric].notna()]
    skipped = len(df) - len(valid)
    if skipped > 0:
        print(f"\n{metric}: {skipped}/{len(df)} entries skipped (parsing failure)")

    low_scores = valid[valid[metric] < 0.5]
    if len(low_scores) > 0:
        print(f"\n{metric} < 0.5 ({len(low_scores)} questions):")
        for _, row in low_scores.iterrows():
            print(f"  - {row['question']} (score: {row[metric]:.3f})")

# Summary interpretation
print("\n" + "=" * 60)
print("INTERPRETATION:")
for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[metric].dropna()
    if len(valid) == 0:
        print(f"  {metric:25s}: NO DATA")
        continue
    avg = valid.mean()
    if avg >= 0.8:
        verdict = "GOOD"
    elif avg >= 0.5:
        verdict = "NEEDS IMPROVEMENT"
    else:
        verdict = "POOR"
    print(f"  {metric:25s}: {avg:.3f} - {verdict}")
# Out:
# DIAGNOSTICS:
# ============================================================
#
# answer_similarity < 0.5 (1 questions):
#   - Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho
# roka? (score: 0.379)
#
# answer_correctness: 1/182 entries skipped (parsing failure)
#
# answer_correctness < 0.5 (56 questions):
#   - Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku
# zdravia? (score: 0.230)
#   - Budú sa finančné príspevky časom meniť? (score: 0.379)
#   - Prečo musím potvrdiť nejaké súhlasy, ak chcem čerpať príspevky z
# Peňaženky zdrav (score: 0.490)
#   - Na čo slúži e-mailová adresa? Je to povinný údaj? Budem dostávať z
# mobilnej apli (score: 0.399)
#   - Môžem čerpať finančné príspevky z Peňaženky zdravia aj bez vytvárania
# skupiny, t (score: 0.397)
#   - Kto môže čerpať finančné príspevky v Peňaženke zdravia MINI? (score: 0.424)
#   - Mám pozvánku do skupiny. Môžem v tomto štádiu čerpať finančné príspevky? (score: 0.426)
#   - Môžem požiadať o finančný príspevok ako fyzická osoba, ak som ako FO – podnikate (score: 0.412)
#   - Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís (score: 0.219)
#   - Ako požiadam o finančný príspevok? (score: 0.384)
#   - Do akej doby musím podať žiadosť? (score: 0.416)
#   - Sú obmedzenia pri podávaní prílohy k žiadosti? (score: 0.421)
#   - Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára? (score: 0.432)
#   - Čo keď mi lekár nedá za ošetrenie doklad? (score: 0.464)
#   - Môžem zmeniť číslo účtu? (score: 0.426)
#   - Prečo ste mi finančný príspevok ešte neuhradili? (score: 0.391)
#   - Žiadosť ste mi ukončili bez úhrady. Môžem ju podať znova? (score: 0.429)
#   - Kde nájdem zmluvných zubárov, u ktorých môžem absolvovať dentálnu hygienu? (score: 0.500)
#   - Na čo je určený finančný príspevok na zuby 1× 40 € ročne? (score: 0.403)
#   - Finančné príspevky na lieky bude môcť čerpať dospelý poistenec aj dieťa? (score: 0.370)
#   - Čerpanie finančného príspevku na lieky je maximálne vo výške 20 € na poistenca n (score: 0.390)
#   - Preplatíte mi aj drahšie lieky? Ak si vyberiem v lekárni liek na predpis a uhrad (score: 0.471)
#   - Môžem požiadať o preplatenie očkovania proti ovčím kiahňam? (score: 0.391)
#   - Ako si požičať monitor dychu? (score: 0.409)
#   - Ako môžem začať používať skupinovú Peňaženku zdravia MAXI? (score: 0.310)
#   - Dokedy si môžem vytvoriť skupinu v Peňaženke zdravia MAXI? (score: 0.394)
#   - Kto je správca? Čo bude robiť? (score: 0.428)
#   - Peňaženka zdravia MAXI je založená na princípe solidarity. Čo to znamená? (score: 0.476)
#   - Je Peňaženka zdravia MAXI iba pre poistencov? (score: 0.206)
#   - Akým spôsobom je možné zdieľať 50 % sumy medzi členmi v skupine? Je potrebné na  (score: 0.480)
#   - Má na to právo len správca skupiny alebo kto o tom rozhoduje? (score: 0.319)
#   - Môže si moje neplnoleté dieťa pridať do skupiny niekto iný, keď mu to odsúhlasím (score: 0.367)
#   - Čo ak správca prestane byť poistencom, zomrie alebo odíde do zahraničia? (score: 0.415)
#   - Ako požiadam o čerpanie finančných príspevkov? (score: 0.411)
#   - Je nejaký čas, dokedy musím žiadosť podať? (score: 0.470)
#   - Sú nejaké obmedzenia pri podávaní prílohy k žiadosti? (score: 0.440)
#   - Som správcom skupiny. Ako si pozriem, kto a koľko si už na príspevky vyčerpal? (score: 0.474)
#   - Som správca skupiny a podávam žiadosť za člena. Musíme mať všetci absolvované pr (score: 0.460)
#   - Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára? (score: 0.453)
#   - Môžem zmeniť číslo účtu? (score: 0.411)
#   - Pošlete mi peniaze aj na zahraničný účet? (score: 0.404)
#   - Kedy mi uhradíte finančný príspevok? (score: 0.494)
#   - Prečo ste mi finančný príspevok ešte neuhradili? (score: 0.493)
#   - Môžem požiadať o príspevok na strojček pre dieťa z Peňaženky zdravia MAXI? (score: 0.475)
#   - Sú v limite 450 € na strojček pre dieťa zahrnuté aj kontroly? (score: 0.456)
#   - Ak je suma na doklade za dentálnu hygienu vyššia ako 40 €, môžem ju rozdeliť do  (score: 0.400)
#   - Ako je to s doplatkami za lieky zo zákona? Strhnú sa mi zo sumy príspevku v Peňa (score: 0.433)
#   - Čerpanie finančného príspevku na lieky a dietetické potraviny pre deti a ich zák (score: 0.327)
#   - Má dieťa nárok na príspevok z Peňaženky zdravia MAXI v prípade, že absolvovalo v (score: 0.487)
#   - Môžem si zakúpiť okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP? (score: 0.443)
#   - Prečo ste stanovili podmienku na absolvovanie laserovej operácie očí od výšky di (score: 0.460)
#   - Môžem požiadať o preplatenie očkovania proti ovčím kiahňam? (score: 0.491)
#   - Ako si požičať monitor dychu? (score: 0.396)
#   - Môže získať finančný príspevok na prenatálne testovanie aj žena vo veku 30 rokov (score: 0.482)
#   - Je možné získať finančný príspevok aj na doplatky za glukózové senzory pre dieťa (score: 0.389)
#   - Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho
# roka? (score: 0.345)
#
# ============================================================
# INTERPRETATION:
#   answer_similarity        : 0.831 - GOOD
#   answer_correctness       : 0.580 - NEEDS IMPROVEMENT

# %% [markdown]
# ## Save Results
#
# Save experiment config and metric results to `results/` for cross-experiment comparison.

# %%
import os

os.makedirs("results", exist_ok=True)

# --- Experiment config ---
experiment_config = {
    "experiment_id": "experiment3",
    "description": "Qwen3-32B",
    "timestamp": datetime.now().isoformat(),
    "eval_model": ragas_llm_model,
    "num_questions": len(eval_data),
}

with open("results/experiment_config.json", "w", encoding="utf-8") as f:
    json.dump(experiment_config, f, ensure_ascii=False, indent=2)
print("Saved results/experiment_config.json")

# --- Save each metric ---
for metric_name in SCORING_FUNCTIONS:
    m_result = {"metric": metric_name, "aggregated": None, "num_scored": 0, "num_skipped": 0, "per_question": []}
    if metric_name in all_scores:
        sr = all_scores[metric_name]
        m_result["aggregated"] = compute_aggregated(sr)
        for i, gen in enumerate(ref_results.generations):
            score = sr.score_rows[i].get("score", None) if i < len(sr.score_rows) else None
            is_valid = score is not None and str(score) != "nan"
            if is_valid:
                m_result["num_scored"] += 1
            else:
                m_result["num_skipped"] += 1
            entry = {"question": gen["user_input"], "score": round(float(score), 4) if is_valid else None}
            entry["response"] = eval_data[i]["response"] if i < len(eval_data) else ""
            entry["reference"] = eval_data[i]["reference"] if i < len(eval_data) else ""
            m_result["per_question"].append(entry)

    filename = f"results/{metric_name}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(m_result, f, ensure_ascii=False, indent=2)
    print(f"Saved {filename} (mean={m_result['aggregated']}, scored={m_result['num_scored']}, skipped={m_result['num_skipped']})")

print("\nAll results saved to results/ directory.")
# Out:
# Saved results/experiment_config.json
# Saved results/answer_similarity.json (mean=0.8311921072830002, scored=182, skipped=0)
# Saved results/answer_correctness.json (mean=0.579982, scored=181, skipped=1)
#
# All results saved to results/ directory.
