# %% [markdown]
# # RAGAS Evaluation: answer_similarity + answer_correctness
#
# Loads cached eval_data (from `query_rag_system.ipynb`) and runs answer quality metrics.
# Metrics are submitted as separate jobs for fault isolation — `answer_similarity` (fast, embedding-only) runs first.
#
# **Prerequisites:**
# - `eval_data_health_wallet.json` generated by `query_rag_system.ipynb`
#
# **Metrics:**
# - `answer_similarity` — Semantic similarity between RAG answer and ground truth (embedding cosine)
# - `answer_correctness` — Factual correctness of answer vs ground truth (F1 + semantic similarity)
#
# **See also:** `ragas_eval_context_metrics.ipynb` for context_precision + context_recall.

# %% [markdown]
# ## Step 0: Setup and Dependencies

# %%
# !pip install -q llama-stack-client==0.4.2 rich pandas

# %%
import json
import time
from datetime import datetime

import pandas as pd
from llama_stack_client import LlamaStackClient
from rich.pretty import pprint


def compute_aggregated(score_result):
    """Compute mean from per-question scores, skipping None/NaN entries.
    Falls back to RAGAS aggregated_results if available."""
    agg = score_result.aggregated_results
    if agg is not None and not (isinstance(agg, dict) and None in agg.values()):
        if isinstance(agg, dict):
            vals = [v for v in agg.values() if v is not None]
            return vals[0] if len(vals) == 1 else agg
        return agg
    scores = []
    for row in score_result.score_rows:
        s = row.get("score")
        if s is not None and str(s) != "nan":
            scores.append(float(s))
    return round(sum(scores) / len(scores), 6) if scores else None

# %%
# --- Configuration ---
RAGAS_URL = "http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321"
PROVIDER_ID_INLINE = "trustyai_ragas_inline"

# %%
ragas_client = LlamaStackClient(base_url=RAGAS_URL)

print("RAGAS system models:")
ragas_models = ragas_client.models.list()
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', '?')
    mtype = getattr(m, 'model_type', '?')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    print(f"  {mid} ({mtype})")

print("\nRAGAS eval providers:")
providers = ragas_client.providers.list()
eval_providers = [p for p in providers if p.api == "eval"]
pprint(eval_providers)
# Out:
# RAGAS system models:
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/models "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/providers "HTTP/1.1 200 OK"
#   vllm-embedding/qwen3-4b-embedding (embedding)
#   vllm-inference/Gemma-3-27B-BF16-Distributed (llm)
#
# RAGAS eval providers:
# [
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'use_k8s': True,
# │   │   │   'base_url': 'http://gemma-3-27b-bf16-distributed-predictor.vszp.svc.cluster.local:8080/v1'
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_lmeval',
# │   │   provider_type='remote::trustyai_lmeval'
# │   ),
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'embedding_model': 'vllm-embedding/qwen3-4b-embedding',
# │   │   │   'ragas_config': {'raise_exceptions': False}
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_ragas_inline',
# │   │   provider_type='inline::trustyai_ragas'
# │   )
# ]

# %% [markdown]
# ## Load Eval Data

# %%
with open("eval_data_health_wallet.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)
print(f"Loaded {len(eval_data)} evaluation entries")
# Out:
# Loaded 182 evaluation entries

# %% [markdown]
# ## Step 4: Run RAGAS Evaluation

# %%
SCORING_FUNCTIONS = [
    "answer_similarity",
    "answer_correctness",
]

# answer_similarity.name returns "semantic_similarity" in ragas 0.3.0
METRIC_ALIASES = {"answer_similarity": "semantic_similarity"}

# Find the LLM model ID in RAGAS system
ragas_llm_model = None
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', None)
    mtype = getattr(m, 'model_type', '')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    if mtype == 'llm':
        ragas_llm_model = mid
        break

assert ragas_llm_model, "No LLM model found in RAGAS system!"
print(f"Using LLM for evaluation: {ragas_llm_model}")


def _resolve_metric_key(scores_dict, metric_name):
    """Find the actual key in scores_dict, checking aliases."""
    if metric_name in scores_dict:
        return metric_name
    alias = METRIC_ALIASES.get(metric_name)
    if alias and alias in scores_dict:
        return alias
    return None


def run_ragas_metric(metric_names, eval_data, label=None):
    """Register dataset + benchmark, run eval, return results or None on failure."""
    label = label or "_".join(metric_names)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    ds_id = f"hw_{label}_{ts}"
    bm_id = f"hw_bench_{label}_{ts}"

    ragas_client.beta.datasets.register(
        dataset_id=ds_id,
        purpose="eval/question-answer",
        source={"type": "rows", "rows": eval_data},
        metadata={"provider_id": "localfs"},
    )
    ragas_client.alpha.benchmarks.register(
        benchmark_id=bm_id,
        dataset_id=ds_id,
        scoring_functions=metric_names,
        provider_id=PROVIDER_ID_INLINE,
    )

    job = ragas_client.alpha.eval.run_eval(
        benchmark_id=bm_id,
        benchmark_config={
            "eval_candidate": {
                "type": "model",
                "model": ragas_llm_model,
                "sampling_params": {"temperature": 0.1, "max_tokens": 1500},
            },
            "scoring_params": {},
        },
    )
    print(f"[{label}] Job {job.job_id} submitted. Metrics: {metric_names}")

    start = time.time()
    while True:
        st = ragas_client.alpha.eval.jobs.status(benchmark_id=bm_id, job_id=job.job_id)
        elapsed = time.time() - start
        print(f"  [{elapsed:.0f}s] {st.status}")
        if st.status in ("completed", "failed"):
            break
        time.sleep(15)

    if st.status == "failed":
        print(f"  FAILED after {elapsed:.0f}s")
        return None

    results = ragas_client.alpha.eval.jobs.retrieve(benchmark_id=bm_id, job_id=job.job_id)
    print(f"  Completed in {elapsed:.0f}s")
    print(f"  Returned score keys: {list(results.scores.keys())}")
    for mn in metric_names:
        key = _resolve_metric_key(results.scores, mn)
        if key:
            agg = compute_aggregated(results.scores[key])
            print(f"  {mn}: {agg}")
        else:
            print(f"  {mn}: NOT FOUND in results")
    return results
# Out:
# Using LLM for evaluation: vllm-inference/Gemma-3-27B-BF16-Distributed

# %%
# Job 1: answer_similarity (embedding-only, fast)
results_sim = run_ragas_metric(["answer_similarity"], eval_data, label="similarity")
# Out:
# /tmp/ipykernel_2138/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_2138/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260508_151355/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260508_151355/jobs/1 "HTTP/1.1 200 OK"
# [similarity] Job 1 submitted. Metrics: ['answer_similarity']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260508_151355/jobs/1 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260508_151355/jobs/1 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260508_151355/jobs/1/result "HTTP/1.1 200 OK"
#   [30s] completed
#   Completed in 30s
#   Returned score keys: ['semantic_similarity']
#   answer_similarity: 0.855497314025794

# %%
# Job 2: answer_correctness (LLM-based, slower)
results_corr = run_ragas_metric(["answer_correctness"], eval_data, label="correctness")
# Out:
# /tmp/ipykernel_2138/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_2138/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
# [correctness] Job 2 submitted. Metrics: ['answer_correctness']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [30s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [45s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [60s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [75s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [90s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [105s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [120s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [135s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [150s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [165s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [180s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [195s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [210s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [225s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [240s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [255s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [270s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [285s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [300s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [315s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [330s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [345s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [360s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [375s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [390s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [405s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [420s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [435s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [450s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [466s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [481s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [496s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [511s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [526s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [541s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [556s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [571s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [586s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [601s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [616s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [631s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [646s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [661s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [676s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [691s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [706s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [721s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [736s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [751s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [766s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [781s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [796s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [811s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [826s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [841s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [856s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [871s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [886s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [901s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [916s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [931s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [946s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [961s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [976s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [991s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1006s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1021s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1036s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1051s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1066s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1081s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1096s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1111s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1126s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1141s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1156s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1171s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1186s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1201s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1216s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1231s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1246s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1261s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1276s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1291s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1306s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1321s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1336s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1351s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1366s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1381s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1396s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1411s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1426s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1442s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1457s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1472s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1487s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1502s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1517s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1532s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1547s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1562s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1577s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1592s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1607s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1622s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1637s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1652s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1667s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1682s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1697s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1712s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1727s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1742s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1757s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1772s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1787s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1802s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1817s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1832s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1847s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1862s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1877s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1892s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1907s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1922s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1937s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1952s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1967s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1982s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [1997s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2012s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2027s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2042s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2057s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2072s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2087s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2102s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2117s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2132s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2147s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2162s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2177s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2192s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2207s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2222s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2237s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2252s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2267s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2282s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2297s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2312s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2327s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2343s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2358s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2373s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2388s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2403s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2418s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2433s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2448s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2463s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2478s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2493s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2508s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2523s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2538s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2553s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2568s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2583s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2598s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2613s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2628s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2643s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2658s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2673s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2688s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2703s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2718s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2733s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2748s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2763s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2778s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2793s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2808s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2823s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2838s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2853s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2868s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2883s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2898s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2913s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2928s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2943s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2958s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2973s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [2988s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3003s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3018s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3033s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3048s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3063s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3078s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3093s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3108s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3123s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3138s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3153s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3168s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3183s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3198s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3213s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3228s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3243s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3258s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3273s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3288s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3304s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3319s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3334s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [3349s] in_progress
# ...
#   [6051s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6066s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6081s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6096s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6111s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6126s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6141s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6156s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6171s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6186s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6201s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6217s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6232s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6247s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6262s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6277s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6292s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6307s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6322s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6337s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6352s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6367s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6382s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6397s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6412s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6427s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6442s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6457s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6472s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6487s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6502s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6517s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6532s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6547s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6562s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6577s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6592s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6607s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6622s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6637s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6652s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6667s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6682s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6697s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6712s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6727s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6742s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6757s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6772s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6787s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6802s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6817s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6832s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6847s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6862s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6877s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6892s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6907s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6922s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6937s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6952s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6967s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6982s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [6997s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7012s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7027s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7042s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7057s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7072s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7087s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7102s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7117s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7132s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
#   [7147s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260508_151426/jobs/2/result "HTTP/1.1 200 OK"
#   [7163s] completed
#   Completed in 7163s
#   Returned score keys: ['answer_correctness']
#   answer_correctness: 0.6910561723240746

# %% [markdown]
# ## Step 5: Results Analysis

# %%
# Merge scores from both jobs, normalizing metric names
all_scores = {}
ref_results = None
for r in [results_sim, results_corr]:
    if r is not None:
        ref_results = ref_results or r
        for mn, sr in r.scores.items():
            all_scores[mn] = sr

# Normalize: map aliases back to canonical names (e.g. semantic_similarity -> answer_similarity)
reverse_aliases = {v: k for k, v in METRIC_ALIASES.items()}
for alias, canonical in reverse_aliases.items():
    if alias in all_scores and canonical not in all_scores:
        all_scores[canonical] = all_scores.pop(alias)

# Build results DataFrame
rows = []
if ref_results:
    for i, gen in enumerate(ref_results.generations):
        row = {"question": gen["user_input"][:80]}
        for metric in SCORING_FUNCTIONS:
            if metric in all_scores:
                score_rows = all_scores[metric].score_rows
                if i < len(score_rows):
                    score = score_rows[i].get("score", None)
                    if score is not None and str(score) != "nan":
                        row[metric] = score
                    else:
                        row[metric] = None
        rows.append(row)

df = pd.DataFrame(rows)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Summary
print("=" * 80)
print("RAGAS EVALUATION RESULTS - Health Wallet RAG")
print("=" * 80)
print(f"\nEval Data:    {len(eval_data)} questions")
print(f"Timestamp:    {timestamp}")
print()

print("AGGREGATED SCORES:")
print("-" * 40)
for metric in SCORING_FUNCTIONS:
    if metric in all_scores:
        sr = all_scores[metric]
        agg = compute_aggregated(sr)
        scored = sum(1 for r in sr.score_rows if r.get("score") is not None and str(r.get("score")) != "nan")
        skipped = len(sr.score_rows) - scored
        suffix = f" ({skipped} skipped)" if skipped > 0 else ""
        print(f"  {metric:25s}: {agg}{suffix}")
    else:
        print(f"  {metric:25s}: FAILED")
print()
# Out:
# ================================================================================
# RAGAS EVALUATION RESULTS - Health Wallet RAG
# ================================================================================
#
# Eval Data:    182 questions
# Timestamp:    20260508_171349
#
# AGGREGATED SCORES:
# ----------------------------------------
#   answer_similarity        : 0.855497314025794
#   answer_correctness       : 0.6910561723240746

# %%
# Per-question breakdown
print("PER-QUESTION SCORES:")
print("-" * 80)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', 200)
print(df.to_string(index=False))
# Out:
# PER-QUESTION SCORES:
# --------------------------------------------------------------------------------
#                                                                          question  answer_similarity  answer_correctness
#                                     Kde nájdem Peňaženku zdravia? Je spoplatnená?           0.942675            0.535669
#                          Prečo je Peňaženka zdravia viazaná na mobilnú aplikáciu?           0.928853            0.565547
# Na čerpanie príspevkov z Peňaženky zdravia musím mať mobilnú aplikáciu,\nalebo mi           1.000000            1.000000
# Ak som sa opäť vrátil do VšZP, môžem pre Peňaženku zdravia využívať svoje\nstaré            0.999946            0.892857
#       Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku\nzdravia?           0.629435            0.251188
# Aktualizácia mobilnej aplikácie prebehne automaticky, alebo si novú verziu\nmusím           0.732391            0.433080
# Máte kontakt na podporu pre klientov? Mám problémy s inštaláciou mobilnej\napliká           0.811363            0.765541
#  Prečo je potrebná aktivácia mobilnej aplikácie? Nie je to zbytočná strata\nčasu?           0.827545            0.606789
#               Ak mám nový telefón, musím si opätovne aktivovať mobilnú aplikáciu?           0.869642            0.967505
# Ak si nanovo zaktivujem aplikáciu, musím si opätovne vytvoriť aj skupinu v\nPeňaž           0.999949            1.000000
#                                           Budú sa finančné príspevky časom meniť?           0.795012            0.471573
# Prečo musím potvrdiť nejaké súhlasy, ak chcem čerpať príspevky z\nPeňaženky zdrav           0.999941            1.000000
# Na čo slúži e-mailová adresa? Je to povinný údaj? Budem dostávať z\nmobilnej apli           0.798918            0.449565
# Kde nájdem presný zoznam finančných príspevkov, ktoré môžem čerpať z\nPeňaženky z           0.889363            0.568483
# Môžem čerpať finančné príspevky z Peňaženky zdravia aj bez vytvárania\nskupiny, t           0.968242            0.842039
#                               Aký limit finančných prostriedkov mám k dispozícii?           0.951570            0.988001
#                      Kto môže čerpať finančné príspevky v Peňaženke zdravia MINI?           0.915797            0.478669
#          Mám pozvánku do skupiny. Môžem v tomto štádiu čerpať finančné príspevky?           0.864329            0.569120
#  Začal som vytvárať skupinu, sme zatiaľ 2 a neviem, kedy sa nám podarí vytvoriť s           0.988032            0.847004
#                 Môže finančné príspevky z Peňaženky zdravia MINI čerpať aj dieťa?           0.973997            0.618565
#  Aký je postup čerpania finančných príspevkov z Peňaženky zdravia MINI pre dieťa?           0.825645            0.506361
#  Môžem ako dospelý v Peňaženke zdravia MINI konať aj za dieťa, ktoré mi bolo zver           0.853180            0.963500
#  Môže požiadať o čerpanie finančných príspevkov z Peňaženky zdravia MINI aj osoba           0.749152            0.687516
#  Môžem požiadať o finančný príspevok ako fyzická osoba, ak som ako FO – podnikate           0.800284            0.950070
#  Po príchode zo zahraničia sa poistím vo VšZP. Môžem požiadať o finančný príspevo           0.868186            0.716879
#  Preplatíte mi žiadosť o finančný príspevok v prípade, že odídem do zahraničia a            0.858497            0.777132
#  Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís           0.764348            0.491103
#                                                Ako požiadam o finančný príspevok?           0.849139            0.452408
#                                                 Do akej doby musím podať žiadosť?           0.999943            1.000000
#                  Čo potrebujem k podaniu žiadosti? Kde a ako mám žiadosť vyplniť?           0.858637            0.623811
#                                    Sú obmedzenia pri podávaní prílohy k žiadosti?           0.758393            0.510895
#                                                 Ako zistím, kto je zmluvný lekár?           0.952608            0.738235
#  Môžem si podať žiadosť o finančný príspevok aj v prípade, že som navštívil súkro           0.778047            0.569385
#                              Musím mať absolvované všetky preventívne prehliadky?           0.908386            0.752162
#                Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára?           0.839329            0.556184
#                                         Čo keď mi lekár nedá za ošetrenie doklad?           0.765839            0.472519
#                               Ako si pozriem, koľko som už na príspevky vyčerpal?           0.739736            0.545004
#                               Ako si do Peňaženky zdravia MINI vložím číslo účtu?           0.861754            0.590606
#                                                          Môžem zmeniť číslo účtu?           0.726488            0.431329
#                                         Pošlete mi peniaze aj na zahraničný účet?           0.904024            0.601010
#                                                Kedy zasielate finančné príspevky?           0.792605            0.904473
#  Môžem podať žiadosť, aj keď žiadam o finančný príspevok v sume vyššej, ako je su           0.769012            0.791984
#                                  Prečo ste mi finančný príspevok ešte neuhradili?           0.723923            0.467181
#               Akou formou sa dozviem o stave mojej žiadosti o finančný príspevok?           0.852849            0.712993
#               Žiadosť ste mi ukončili bez úhrady, čo mám robiť? Ako zistím dôvod?           0.839857            0.739467
#                                        Môžem podať viac žiadostí na jeden doklad?           0.921054            0.730334
#                         Žiadosť ste mi ukončili bez úhrady. Môžem ju podať znova?           0.979404            0.844916
#           Budem musieť vrátiť príspevok, ak v nasledujúcom roku zmením poisťovňu?           0.704040            0.551002
#             Aké finančné príspevky na zuby môžem čerpať v Peňaženke zdravia MINI?           0.923015            0.530731
#        Kde nájdem zmluvných zubárov, u ktorých môžem absolvovať dentálnu hygienu?           0.686031            0.671389
#                         Na čo je určený finančný príspevok na zuby 1× 40 € ročne?           0.860045            0.364962
#                Na ktoré výkony dentálnej hygieny sa vzťahuje limit 1× 40 € ročne?           0.782975            0.758063
#  Môžem použiť príspevok 1× 30 € ročne na strojček pre dieťa z Peňaženky zdravia M           0.987724            0.823854
#          Finančné príspevky na lieky bude môcť čerpať dospelý poistenec aj dieťa?           0.686708            0.385966
#               Vzťahuje sa finančný príspevok na lieky aj na dietetické potraviny?           0.832249            0.617119
#  Ako je to s doplatkami za lieky zo zákona? Strhnú sa mi zo sumy príspevku v Peňa           0.970721            0.716392
#  Čerpanie finančného príspevku na lieky je maximálne vo výške 20 € na poistenca n           0.843184            0.425371
#  Preplatíte mi aj drahšie lieky? Ak si vyberiem v lekárni liek na predpis a uhrad           0.831575            0.553946
#  V lekárni mi namiešali masť alebo kvapky. Môžem v tomto prípade požiadať o finan           0.893802            0.973419
#  Má dieťa nárok na finančný príspevok z Peňaženky zdravia MINI v prípade, že abso           0.697490            0.474181
#             Môžem získať z Peňaženky zdravia MINI príspevok na kontaktné šošovky?           0.926941            0.981719
#     Môžem si prevziať okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP?           0.765055            0.378752
#    Je nejaké obmedzenie výšky dioptrie na príspevok okuliarový rám pre dospelých?           0.787259            0.796899
#  Aké podmienky musím splniť, aby som dostal príspevok na okuliarový rám pre dospe           0.818906            0.621544
#  Príspevok pre deti 100 € platí samostatne na okuliarový rám a aj na okuliarové š           0.999782            0.999947
#     Je členstvo v športovom klube podmienkou na príspevok na športovú prehliadku?           0.913594            0.920782
#  Je možné čerpať finančný príspevok aj pri preočkovaní, napríklad pri kliešťovej            0.923913            0.906015
#  Preplatíte každú dávku očkovania alebo musím mať všetky odporúčané vakcíny podľa           0.997952            0.999473
#  Na aké špeciálne samotesty si môžem finančný príspevok uplatniť a do akej výšky?           0.956086            0.895183
#                       Môžem požiadať o preplatenie očkovania proti ovčím kiahňam?           0.844761            0.961237
#                                                     Ako si požičať monitor dychu?           0.878677            0.469686
#  Aká je maximálna výška príspevku, ktorú môže žena získať na moderné cytologické            0.914823            0.978784
#                        Ako môžem začať používať skupinovú Peňaženku zdravia MAXI?           0.799189            0.310807
#                        Dokedy si môžem vytvoriť skupinu v Peňaženke zdravia MAXI?           0.812830            0.403137
#                                                    Kto je správca? Čo bude robiť?           0.857788            0.526771
#                                                           Ako sa stanem správcom?           0.926594            0.898204
#                                   Ako pridám člena? Aké údaje o ňom musím vedieť?           0.826255            0.635359
#                                         Pridá sa mi dieťa do skupiny automaticky?           0.987437            0.928662
#                                                             Ako sa stanem členom?           0.736276            0.640710
#                                       Ako uvidím, že ma niekto pozval do skupiny?           0.771608            0.592752
#  Keď si pridám do Peňaženky zdravia MAXI člena, ktorý nemá nainštalovanú mobilnú            0.999950            1.000000
#                       Ako sa správca dozvie, že som potvrdil prijatie do skupiny?           0.778150            0.603557
#  Chcem niekoho pridať, ale ukazuje mi, že už je v inej skupine. Ako si ho pridám?           0.967097            0.941853
#  Môžem si pridať do skupiny v Peňaženke zdravia MAXI okrem rodiny a príbuzných aj           0.868579            0.779458
#         Peňaženka zdravia MAXI je založená na princípe solidarity. Čo to znamená?           0.925035            0.572116
#  Čo so staršími ľuďmi, ktorí nemajú mobil? Ako môžu využiť finančné príspevky z P           0.746980            0.660722
#                                     Je Peňaženka zdravia MAXI iba pre poistencov?           0.818827            0.204670
#  Keď chcem pridať do svojej skupiny osobu pozbavenú spôsobilosti na právne úkony,           0.843099            0.960775
#                            V roku 2024 som bol v skupine. Prečo ju teraz nevidím?           0.997514            0.999387
#  Ak som už členom/správcom aktívnej skupiny, bude táto skupina pokračovať aj v na           0.815842            0.297584
#  Kde nájdem presný zoznam poskytovaných finančných príspevkov v rámci Peňaženky z           0.840527            0.638614
#       Kedy môže skupina začať čerpať finančný príspevok z Peňaženky zdravia MAXI?           0.745375            0.561739
#  Akým spôsobom je možné zdieľať 50 % sumy medzi členmi v skupine? Je potrebné na            0.781586            0.495388
#                     Má na to právo len správca skupiny alebo kto o tom rozhoduje?           0.719923            0.280172
#                    Zdieľanú sumu je možné využiť na akýkoľvek finančný príspevok?           0.856857            0.514449
#  V prípade, že člen už určitú časť svojej sumy minul a má k dispozícii napríklad            0.805666            0.451283
#  Môže si moje neplnoleté dieťa pridať do skupiny niekto iný, keď mu to odsúhlasím           0.807676            0.452036
#  Môžem sa stať členom Peňaženky zdravia MAXI ako fyzická osoba, ak som ako FO – p           0.649835            0.537051
#                                                           Môžem odísť zo skupiny?           0.836392            0.459198
#                                          Môže správca niekoho vyradiť zo skupiny?           0.934981            0.421192
#  Čo ak prídem zo zahraničia a poistím sa vo VšZP? Môžem sa pripojiť do skupiny? D           0.729919            0.557581
#  Čo keď odídem do zahraničia a ukončím poistenie vo VšZP? Dostanem finančný prísp           0.787157            0.946824
#          Čo ak správca prestane byť poistencom, zomrie alebo odíde do zahraničia?           0.868282            0.592138
#     Čo ak sme 3 členovia s nárokom v skupine a niekto odíde do zahraničia/zomrie?           0.874337            0.647001
#                                    Ako požiadam o čerpanie finančných príspevkov?           0.826688            0.394167
#  Som správca, musím podať žiadosť o finančný príspevok za každého člena individuá           0.931988            0.983024
#                                        Je nejaký čas, dokedy musím žiadosť podať?           0.854649            0.642322
#                  Čo potrebujem k podaniu žiadosti? Kde a ako mám žiadosť vyplniť?           0.782414            0.545703
#                             Sú nejaké obmedzenia pri podávaní prílohy k žiadosti?           0.737782            0.709263
#                                               Prečo si nemôžem podať žiadosť sám?           0.999947            1.000000
#                                                 Ako zistím, kto je zmluvný lekár?           0.943220            0.664322
#  Môžem si dať preplatiť doklad o úhrade aj od súkromného lekára alebo zariadenia?           0.881297            0.745246
#    Som správcom skupiny. Ako si pozriem, kto a koľko si už na príspevky vyčerpal?           0.890379            0.784970
#                         Kde uvidím, koľko si dali preplatiť iní členovia skupiny?           0.999955            1.000000
#                              Musím mať absolvované všetky preventívne prehliadky?           0.917742            0.792111
#  Som správca skupiny a podávam žiadosť za člena. Musíme mať všetci absolvované pr           0.880405            0.970101
#                Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára?           0.800866            0.376776
#                          Musia mať všetci v našej skupine preventívne prehliadky?           0.897091            0.545816
#                                            Máme v skupine dlžníka. Čo máme robiť?           0.818579            0.645642
#                                         Čo keď mi lekár nedá za ošetrenie doklad?           0.799057            0.414077
#                                                        Na aký účet prídu peniaze?           0.945559            0.736330
#                               Ako si do Peňaženky zdravia MAXI vložím číslo účtu?           0.812852            0.703246
#                                                          Môžem zmeniť číslo účtu?           0.795866            0.699012
#                                         Pošlete mi peniaze aj na zahraničný účet?           0.999941            1.000000
#                                              Kedy mi uhradíte finančný príspevok?           0.817234            0.704418
#       Môžem podať žiadosť, aj keď žiadam viac, ako je výška sumy v našej skupine?           0.715831            0.607492
#  Môžem podať žiadosť, aj keď žiadam o finančný príspevok v sume vyššej, ako je su           0.767935            0.791984
#                                  Prečo ste mi finančný príspevok ešte neuhradili?           0.694150            0.293529
#               Akou formou sa dozviem o stave mojej žiadosti o finančný príspevok?           0.839155            0.959960
#               Žiadosť ste mi ukončili bez úhrady, čo mám robiť? Ako zistím dôvod?           0.770536            0.714253
#                                        Môžem podať viac žiadostí na jeden doklad?           0.942406            0.878419
#                         Žiadosť ste mi ukončili bez úhrady. Môžem ju podať znova?           0.906759            0.655398
#  Budem musieť vrátiť finančný príspevok, ak v nasledujúcom roku zmením poisťovňu?           0.744945            0.786213
#             Aké finančné príspevky na zuby môžem čerpať v Peňaženke zdravia MAXI?           0.890908            0.631679
#        Kde nájdem zmluvných zubárov, u ktorých môžem absolvovať dentálnu hygienu?           0.685556            0.671389
#                           Na čo je určený finančný príspevok na zuby 2× 40 ročne?           0.838134            0.530843
#                Na ktoré výkony dentálnej hygieny sa vzťahuje limit 2× 40 € ročne?           0.775744            0.756132
#        Môžem požiadať o príspevok na strojček pre dieťa z Peňaženky zdravia MAXI?           0.922259            0.576818
#                     Sú v limite 450 € na strojček pre dieťa zahrnuté aj kontroly?           0.636546            0.587820
#  Je možné u dieťaťa čerpať benefit z Peňaženky zdravia MAXI na strojček, ak je vý           0.874386            0.668623
#  Ak je suma na doklade za dentálnu hygienu vyššia ako 40 €, môžem ju rozdeliť do            0.538671            0.434495
#  Finančné príspevky vo výške 200 € na lieky, dietetické potraviny budú môcť čerpa           0.939337            0.634821
#  Majú nárok na finančný príspevok na lieky v Peňaženke zdravia MAXI aj dospelí, k           0.883261            0.970603
#  Ako je to s doplatkami za lieky zo zákona? Strhnú sa mi zo sumy príspevku v Peňa           0.969155            0.683514
#  Čerpanie finančného príspevku na lieky a dietetické potraviny pre deti a ich zák           0.980682            0.745192
#  Preplatíte mi aj drahšie lieky? Ak si vyberiem v lekárni liek na predpis a uhrad           0.823221            0.580766
#  Môžem čerpať finančný príspevok na lieky a dietetické potraviny ako zákonný zást           0.888471            0.452962
#  V lekárni mi namiešali masť alebo kvapky, môžem pri nich požiadať o finančný prí           0.850100            0.774947
#  Má dieťa nárok na príspevok z Peňaženky zdravia MAXI v prípade, že absolvovalo v           0.693754            0.506768
#             Môžem získať z Peňaženky zdravia MAXI príspevok na kontaktné šošovky?           0.925621            0.981431
#      Môžem si zakúpiť okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP?           0.798464            0.533207
#  Vzťahuje sa príspevok do výšky 450 € na laserovú operáciu excimerovým alebo femt           0.996832            0.999194
#  Vzťahuje sa príspevok do výšky 450 € na laserovú operáciu excimerovým alebo femt           0.996776            0.999194
#               Je možné absolvovať laserovú operáciu očí aj na nezmluvnej klinike?           0.845727            0.661366
#  Mám sivý zákal oka. Je možné príspevok na laserovú operáciu použiť aj na tento ú           0.759339            0.535739
#  Mám dcéru, ktorá má 16 rokov. Je možné použiť príspevok na laserovú operáciu aj            0.856267            0.963770
#  Prečo ste stanovili podmienku na absolvovanie laserovej operácie očí od výšky di           0.936919            0.534276
#  Je možné získať príspevok do maximálnej výšky 450 € aj na operáciu dioptrickej v           0.971120            0.992803
#    Je nejaké obmedzenie výšky dioptrie na príspevok okuliarový rám pre dospelých?           0.877577            0.819276
#  Aké podmienky musím splniť, aby som príspevok na okuliarový rám pre dospelých do           0.790015            0.550233
#  Príspevok pre deti 100 € platí samostatne na okuliarový rám a aj na okuliarové š           0.993702            0.998425
#     Je členstvo v športovom klube podmienkou na príspevok na športovú prehliadku?           0.963601            0.840857
#  Dá sa finančný príspevok uplatniť aj pri preočkovaní, napríklad pri kliešťovej e           0.993520            0.998395
#  Preplatíte každú dávku očkovania alebo musím mať všetky odporúčané vakcíny podľa           0.936933            0.984177
#  Kto si môže uplatniť finančný príspevok z Peňaženky zdravia na očkovanie proti v           0.922699            0.605787
#  Na aké špeciálne samotesty si môžem finančný príspevok uplatniť a do akej výšky?           0.949969            0.820831
#                       Môžem požiadať o preplatenie očkovania proti ovčím kiahňam?           0.844324            0.811056
#                                                     Ako si požičať monitor dychu?           0.896985            0.524305
#  Do akej maximálnej výšky a na aké typy testov si môžem uplatniť finančný príspev           0.969089            0.703943
#  Môže získať finančný príspevok na prenatálne testovanie aj žena vo veku 30 rokov           0.999944            1.000000
#  Aká je maximálna výška finančného príspevku, ktorú môže žena získať na moderné c           0.923062            0.793261
#  Je potrebný predchádzajúci súhlas poisťovne na získanie finančného príspevku na            0.739480            0.684736
#  Je potrebný predchádzajúci súhlas poisťovne na získanie príspevku na 4.cyklus as           0.746894            0.615377
#  Dá sa získať finančný príspevok aj na 4. cyklus asistovanej reprodukcie IVF mimo           0.860129            0.715111
#  Má nárok na získanie finančný príspevku na 4.cyklus asistovanej reprodukcie IVF            0.861978            0.402852
#  Je možné v rámci finančného príspevku 100 €/ročne na doplatky za glukózové senzo           0.983311            0.995822
#  Prečo je stanovená podmienka uplatnenia finančného príspevku na glukózové senzor           0.940673            0.735034
#  Je možné získať finančný príspevok aj na doplatky za glukózové senzory pre dieťa           0.593774            0.448094
#                              Pre akú skupinu diabetikov platí finančný príspevok?           0.999950            1.000000
#     Za akých podmienok môžem zmeniť Peňaženku zdravia MINI na MAXI alebo\nnaopak?           0.994038            0.904777
#     Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho\nroka?           0.448447            0.861923
#  Čo sa stane s mojimi finančnými prostriedkami, ktoré som čerpal pred zmenou typu           0.905751            0.559553

# %%
# Identify weak spots
print("\nDIAGNOSTICS:")
print("=" * 60)

for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[df[metric].notna()]
    skipped = len(df) - len(valid)
    if skipped > 0:
        print(f"\n{metric}: {skipped}/{len(df)} entries skipped (parsing failure)")

    low_scores = valid[valid[metric] < 0.5]
    if len(low_scores) > 0:
        print(f"\n{metric} < 0.5 ({len(low_scores)} questions):")
        for _, row in low_scores.iterrows():
            print(f"  - {row['question']} (score: {row[metric]:.3f})")

# Summary interpretation
print("\n" + "=" * 60)
print("INTERPRETATION:")
for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[metric].dropna()
    if len(valid) == 0:
        print(f"  {metric:25s}: NO DATA")
        continue
    avg = valid.mean()
    if avg >= 0.8:
        verdict = "GOOD"
    elif avg >= 0.5:
        verdict = "NEEDS IMPROVEMENT"
    else:
        verdict = "POOR"
    print(f"  {metric:25s}: {avg:.3f} - {verdict}")
# Out:
# DIAGNOSTICS:
# ============================================================
#
# answer_similarity < 0.5 (1 questions):
#   - Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho
# roka? (score: 0.448)
#
# answer_correctness < 0.5 (34 questions):
#   - Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku
# zdravia? (score: 0.251)
#   - Aktualizácia mobilnej aplikácie prebehne automaticky, alebo si novú verziu
# musím (score: 0.433)
#   - Budú sa finančné príspevky časom meniť? (score: 0.472)
#   - Na čo slúži e-mailová adresa? Je to povinný údaj? Budem dostávať z
# mobilnej apli (score: 0.450)
#   - Kto môže čerpať finančné príspevky v Peňaženke zdravia MINI? (score: 0.479)
#   - Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís (score: 0.491)
#   - Ako požiadam o finančný príspevok? (score: 0.452)
#   - Čo keď mi lekár nedá za ošetrenie doklad? (score: 0.473)
#   - Môžem zmeniť číslo účtu? (score: 0.431)
#   - Prečo ste mi finančný príspevok ešte neuhradili? (score: 0.467)
#   - Na čo je určený finančný príspevok na zuby 1× 40 € ročne? (score: 0.365)
#   - Finančné príspevky na lieky bude môcť čerpať dospelý poistenec aj dieťa? (score: 0.386)
#   - Čerpanie finančného príspevku na lieky je maximálne vo výške 20 € na poistenca n (score: 0.425)
#   - Má dieťa nárok na finančný príspevok z Peňaženky zdravia MINI v prípade, že abso (score: 0.474)
#   - Môžem si prevziať okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP? (score: 0.379)
#   - Ako si požičať monitor dychu? (score: 0.470)
#   - Ako môžem začať používať skupinovú Peňaženku zdravia MAXI? (score: 0.311)
#   - Dokedy si môžem vytvoriť skupinu v Peňaženke zdravia MAXI? (score: 0.403)
#   - Je Peňaženka zdravia MAXI iba pre poistencov? (score: 0.205)
#   - Ak som už členom/správcom aktívnej skupiny, bude táto skupina pokračovať aj v na (score: 0.298)
#   - Akým spôsobom je možné zdieľať 50 % sumy medzi členmi v skupine? Je potrebné na  (score: 0.495)
#   - Má na to právo len správca skupiny alebo kto o tom rozhoduje? (score: 0.280)
#   - V prípade, že člen už určitú časť svojej sumy minul a má k dispozícii napríklad  (score: 0.451)
#   - Môže si moje neplnoleté dieťa pridať do skupiny niekto iný, keď mu to odsúhlasím (score: 0.452)
#   - Môžem odísť zo skupiny? (score: 0.459)
#   - Môže správca niekoho vyradiť zo skupiny? (score: 0.421)
#   - Ako požiadam o čerpanie finančných príspevkov? (score: 0.394)
#   - Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára? (score: 0.377)
#   - Čo keď mi lekár nedá za ošetrenie doklad? (score: 0.414)
#   - Prečo ste mi finančný príspevok ešte neuhradili? (score: 0.294)
#   - Ak je suma na doklade za dentálnu hygienu vyššia ako 40 €, môžem ju rozdeliť do  (score: 0.434)
#   - Môžem čerpať finančný príspevok na lieky a dietetické potraviny ako zákonný zást (score: 0.453)
#   - Má nárok na získanie finančný príspevku na 4.cyklus asistovanej reprodukcie IVF  (score: 0.403)
#   - Je možné získať finančný príspevok aj na doplatky za glukózové senzory pre dieťa (score: 0.448)
#
# ============================================================
# INTERPRETATION:
#   answer_similarity        : 0.855 - GOOD
#   answer_correctness       : 0.691 - NEEDS IMPROVEMENT

# %% [markdown]
# ## Save Results
#
# Save experiment config and metric results to `results/` for cross-experiment comparison.

# %%
import os

os.makedirs("results", exist_ok=True)

# --- Experiment config ---
experiment_config = {
    "experiment_id": "experiment2",
    "description": "Baseline: EuroLLM-22B-instruct",
    "timestamp": datetime.now().isoformat(),
    "eval_model": ragas_llm_model,
    "num_questions": len(eval_data),
}

with open("results/experiment_config.json", "w", encoding="utf-8") as f:
    json.dump(experiment_config, f, ensure_ascii=False, indent=2)
print("Saved results/experiment_config.json")

# --- Save each metric ---
for metric_name in SCORING_FUNCTIONS:
    m_result = {"metric": metric_name, "aggregated": None, "num_scored": 0, "num_skipped": 0, "per_question": []}
    if metric_name in all_scores:
        sr = all_scores[metric_name]
        m_result["aggregated"] = compute_aggregated(sr)
        for i, gen in enumerate(ref_results.generations):
            score = sr.score_rows[i].get("score", None) if i < len(sr.score_rows) else None
            is_valid = score is not None and str(score) != "nan"
            if is_valid:
                m_result["num_scored"] += 1
            else:
                m_result["num_skipped"] += 1
            entry = {"question": gen["user_input"], "score": round(float(score), 4) if is_valid else None}
            entry["response"] = eval_data[i]["response"] if i < len(eval_data) else ""
            entry["reference"] = eval_data[i]["reference"] if i < len(eval_data) else ""
            m_result["per_question"].append(entry)

    filename = f"results/{metric_name}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(m_result, f, ensure_ascii=False, indent=2)
    print(f"Saved {filename} (mean={m_result['aggregated']}, scored={m_result['num_scored']}, skipped={m_result['num_skipped']})")

print("\nAll results saved to results/ directory.")
# Out:
# Saved results/experiment_config.json
# Saved results/answer_similarity.json (mean=0.855497314025794, scored=182, skipped=0)
# Saved results/answer_correctness.json (mean=0.6910561723240746, scored=182, skipped=0)
#
# All results saved to results/ directory.
