# %% [markdown]
# # RAGAS Evaluation: answer_similarity + answer_correctness
#
# Loads cached eval_data (from `query_rag_system.ipynb`) and runs answer quality metrics.
# Metrics are submitted as separate jobs for fault isolation — `answer_similarity` (fast, embedding-only) runs first.
#
# **Prerequisites:**
# - `eval_data_health_wallet.json` generated by `query_rag_system.ipynb`
#
# **Metrics:**
# - `answer_similarity` — Semantic similarity between RAG answer and ground truth (embedding cosine)
# - `answer_correctness` — Factual correctness of answer vs ground truth (F1 + semantic similarity)
#
# **See also:** `ragas_eval_context_metrics.ipynb` for context_precision + context_recall.

# %% [markdown]
# ## Step 0: Setup and Dependencies

# %%
# !pip install -q llama-stack-client==0.4.2 rich pandas

# %%
import json
import time
from datetime import datetime

import pandas as pd
from llama_stack_client import LlamaStackClient
from rich.pretty import pprint


def compute_aggregated(score_result):
    """Compute mean from per-question scores, skipping None/NaN entries.
    Falls back to RAGAS aggregated_results if available."""
    agg = score_result.aggregated_results
    if agg is not None and not (isinstance(agg, dict) and None in agg.values()):
        if isinstance(agg, dict):
            vals = [v for v in agg.values() if v is not None]
            return vals[0] if len(vals) == 1 else agg
        return agg
    scores = []
    for row in score_result.score_rows:
        s = row.get("score")
        if s is not None and str(s) != "nan":
            scores.append(float(s))
    return round(sum(scores) / len(scores), 6) if scores else None

# %%
# --- Configuration ---
RAGAS_URL = "http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321"
PROVIDER_ID_INLINE = "trustyai_ragas_inline"

# %%
ragas_client = LlamaStackClient(base_url=RAGAS_URL)

print("RAGAS system models:")
ragas_models = ragas_client.models.list()
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', '?')
    mtype = getattr(m, 'model_type', '?')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    print(f"  {mid} ({mtype})")

print("\nRAGAS eval providers:")
providers = ragas_client.providers.list()
eval_providers = [p for p in providers if p.api == "eval"]
pprint(eval_providers)
# Out:
# RAGAS system models:
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/models "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1/providers "HTTP/1.1 200 OK"
#   vllm-embedding/qwen3-4b-embedding (embedding)
#   vllm-inference/Gemma-3-27B-BF16-Distributed (llm)
#
# RAGAS eval providers:
# [
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'use_k8s': True,
# │   │   │   'base_url': 'http://gemma-3-27b-bf16-distributed-predictor.vszp.svc.cluster.local:8080/v1'
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_lmeval',
# │   │   provider_type='remote::trustyai_lmeval'
# │   ),
# │   ProviderInfo(
# │   │   api='eval',
# │   │   config={
# │   │   │   'embedding_model': 'vllm-embedding/qwen3-4b-embedding',
# │   │   │   'ragas_config': {'raise_exceptions': False}
# │   │   },
# │   │   health={'status': 'Not Implemented', 'message': 'Provider does not implement health check'},
# │   │   provider_id='trustyai_ragas_inline',
# │   │   provider_type='inline::trustyai_ragas'
# │   )
# ]

# %% [markdown]
# ## Load Eval Data

# %%
with open("eval_data_health_wallet.json", "r", encoding="utf-8") as f:
    eval_data = json.load(f)
print(f"Loaded {len(eval_data)} evaluation entries")
# Out:
# Loaded 182 evaluation entries

# %% [markdown]
# ## Step 4: Run RAGAS Evaluation

# %%
SCORING_FUNCTIONS = [
    "answer_similarity",
    "answer_correctness",
]

# answer_similarity.name returns "semantic_similarity" in ragas 0.3.0
METRIC_ALIASES = {"answer_similarity": "semantic_similarity"}

# Find the LLM model ID in RAGAS system
ragas_llm_model = None
for m in ragas_models:
    mid = getattr(m, 'identifier', None) or getattr(m, 'id', None)
    mtype = getattr(m, 'model_type', '')
    if hasattr(m, 'custom_metadata') and m.custom_metadata:
        mtype = m.custom_metadata.get('model_type', mtype)
    if mtype == 'llm':
        ragas_llm_model = mid
        break

assert ragas_llm_model, "No LLM model found in RAGAS system!"
print(f"Using LLM for evaluation: {ragas_llm_model}")


def _resolve_metric_key(scores_dict, metric_name):
    """Find the actual key in scores_dict, checking aliases."""
    if metric_name in scores_dict:
        return metric_name
    alias = METRIC_ALIASES.get(metric_name)
    if alias and alias in scores_dict:
        return alias
    return None


def run_ragas_metric(metric_names, eval_data, label=None):
    """Register dataset + benchmark, run eval, return results or None on failure."""
    label = label or "_".join(metric_names)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    ds_id = f"hw_{label}_{ts}"
    bm_id = f"hw_bench_{label}_{ts}"

    ragas_client.beta.datasets.register(
        dataset_id=ds_id,
        purpose="eval/question-answer",
        source={"type": "rows", "rows": eval_data},
        metadata={"provider_id": "localfs"},
    )
    ragas_client.alpha.benchmarks.register(
        benchmark_id=bm_id,
        dataset_id=ds_id,
        scoring_functions=metric_names,
        provider_id=PROVIDER_ID_INLINE,
    )

    job = ragas_client.alpha.eval.run_eval(
        benchmark_id=bm_id,
        benchmark_config={
            "eval_candidate": {
                "type": "model",
                "model": ragas_llm_model,
                "sampling_params": {"temperature": 0.1, "max_tokens": 1500},
            },
            "scoring_params": {},
        },
    )
    print(f"[{label}] Job {job.job_id} submitted. Metrics: {metric_names}")

    start = time.time()
    while True:
        st = ragas_client.alpha.eval.jobs.status(benchmark_id=bm_id, job_id=job.job_id)
        elapsed = time.time() - start
        print(f"  [{elapsed:.0f}s] {st.status}")
        if st.status in ("completed", "failed"):
            break
        time.sleep(15)

    if st.status == "failed":
        print(f"  FAILED after {elapsed:.0f}s")
        return None

    results = ragas_client.alpha.eval.jobs.retrieve(benchmark_id=bm_id, job_id=job.job_id)
    print(f"  Completed in {elapsed:.0f}s")
    print(f"  Returned score keys: {list(results.scores.keys())}")
    for mn in metric_names:
        key = _resolve_metric_key(results.scores, mn)
        if key:
            agg = compute_aggregated(results.scores[key])
            print(f"  {mn}: {agg}")
        else:
            print(f"  {mn}: NOT FOUND in results")
    return results
# Out:
# Using LLM for evaluation: vllm-inference/Gemma-3-27B-BF16-Distributed

# %%
# Job 1: answer_similarity (embedding-only, fast)
results_sim = run_ragas_metric(["answer_similarity"], eval_data, label="similarity")
# Out:
# /tmp/ipykernel_3184/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_3184/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_180054/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_180054/jobs/4 "HTTP/1.1 200 OK"
# [similarity] Job 4 submitted. Metrics: ['answer_similarity']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_180054/jobs/4 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_180054/jobs/4 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_similarity_20260509_180054/jobs/4/result "HTTP/1.1 200 OK"
#   [30s] completed
#   Completed in 30s
#   Returned score keys: ['semantic_similarity']
#   answer_similarity: 0.9058946516482095

# %%
# Job 2: answer_correctness (LLM-based, slower)
results_corr = run_ragas_metric(["answer_correctness"], eval_data, label="correctness")
# Out:
# /tmp/ipykernel_3184/3282590118.py:41: DeprecationWarning: deprecated
#   ragas_client.beta.datasets.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1beta/datasets "HTTP/1.1 200 OK"
# /tmp/ipykernel_3184/3282590118.py:47: DeprecationWarning: deprecated
#   ragas_client.alpha.benchmarks.register(
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
# [correctness] Job 5 submitted. Metrics: ['answer_correctness']
#   [0s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [15s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [30s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [45s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [60s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [75s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [90s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [105s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [120s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [135s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [150s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [165s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [180s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [195s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [210s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [225s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [240s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [255s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [270s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [285s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [300s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [315s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [330s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [345s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [360s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [375s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [390s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [405s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [420s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [435s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [451s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [466s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [481s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [496s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [511s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [526s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [541s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [556s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [571s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [586s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [601s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [616s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [631s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [646s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [661s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [676s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [691s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [706s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [721s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [736s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [751s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [766s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [781s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [796s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [811s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [826s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [841s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [856s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [871s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [886s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [901s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [916s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [931s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [946s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [961s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [976s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [991s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1006s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1021s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1036s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1051s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1066s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1081s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1096s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1111s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1126s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1141s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1156s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1171s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1186s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1201s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1216s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1231s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1246s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1261s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1276s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1291s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1306s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1321s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1336s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1351s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1366s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1381s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1396s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1412s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1427s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1442s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1457s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1472s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1487s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1502s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1517s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1532s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1547s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1562s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1577s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1592s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1607s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1622s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1637s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1652s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1667s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1682s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1697s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1712s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1727s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1742s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1757s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1772s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1787s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1802s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1817s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1832s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1847s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1862s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1877s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1892s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1907s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1922s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1937s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1952s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1967s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1982s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [1997s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2012s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2027s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2042s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2057s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2072s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2087s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2102s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2117s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2132s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2147s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2162s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2177s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2192s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2207s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2222s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2237s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2252s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2267s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2282s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2297s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2312s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2327s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2342s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2357s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2372s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2388s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2403s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2418s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2433s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2448s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2463s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2478s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2493s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2508s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2523s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2538s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2553s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2568s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2583s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2598s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2613s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2628s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2643s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2658s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2673s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2688s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2703s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2718s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2733s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2748s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2763s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2778s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2793s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2808s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2823s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2838s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2853s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2868s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2883s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2898s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2913s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2928s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2943s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2958s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2973s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [2988s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3003s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3018s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3033s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3048s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3063s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3078s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3093s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3108s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3123s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3138s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3153s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3168s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3183s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3198s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3213s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3228s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3243s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3258s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3273s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3289s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3304s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3319s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3334s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [3349s] in_progress
# ...
#   [4310s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4325s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4340s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4355s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4370s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4385s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4400s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4415s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4430s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4445s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4460s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4475s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4490s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4505s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4520s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4535s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4550s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4565s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4580s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4595s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4610s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4625s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4640s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4655s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4670s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4685s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4700s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4715s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4730s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4745s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4760s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4775s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4790s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4805s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4820s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4835s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4850s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4865s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4880s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4895s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4910s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4925s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4940s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4955s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4970s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [4986s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5001s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5016s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5031s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5046s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5061s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5076s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5091s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5106s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5121s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5136s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5151s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5166s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5181s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5196s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5211s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5226s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5241s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5256s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5271s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5286s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5301s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5316s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5331s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5346s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5361s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5376s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5391s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
#   [5406s] in_progress
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://llama-stack-ragas-inline-service.ragas-eval.svc.cluster.local:8321/v1alpha/eval/benchmarks/hw_bench_correctness_20260509_180124/jobs/5/result "HTTP/1.1 200 OK"
#   [5426s] completed
#   Completed in 5426s
#   Returned score keys: ['answer_correctness']
#   answer_correctness: 0.7908284338860674

# %% [markdown]
# ## Step 5: Results Analysis

# %%
# Merge scores from both jobs, normalizing metric names
all_scores = {}
ref_results = None
for r in [results_sim, results_corr]:
    if r is not None:
        ref_results = ref_results or r
        for mn, sr in r.scores.items():
            all_scores[mn] = sr

# Normalize: map aliases back to canonical names (e.g. semantic_similarity -> answer_similarity)
reverse_aliases = {v: k for k, v in METRIC_ALIASES.items()}
for alias, canonical in reverse_aliases.items():
    if alias in all_scores and canonical not in all_scores:
        all_scores[canonical] = all_scores.pop(alias)

# Build results DataFrame
rows = []
if ref_results:
    for i, gen in enumerate(ref_results.generations):
        row = {"question": gen["user_input"][:80]}
        for metric in SCORING_FUNCTIONS:
            if metric in all_scores:
                score_rows = all_scores[metric].score_rows
                if i < len(score_rows):
                    score = score_rows[i].get("score", None)
                    if score is not None and str(score) != "nan":
                        row[metric] = score
                    else:
                        row[metric] = None
        rows.append(row)

df = pd.DataFrame(rows)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Summary
print("=" * 80)
print("RAGAS EVALUATION RESULTS - Health Wallet RAG")
print("=" * 80)
print(f"\nEval Data:    {len(eval_data)} questions")
print(f"Timestamp:    {timestamp}")
print()

print("AGGREGATED SCORES:")
print("-" * 40)
for metric in SCORING_FUNCTIONS:
    if metric in all_scores:
        sr = all_scores[metric]
        agg = compute_aggregated(sr)
        scored = sum(1 for r in sr.score_rows if r.get("score") is not None and str(r.get("score")) != "nan")
        skipped = len(sr.score_rows) - scored
        suffix = f" ({skipped} skipped)" if skipped > 0 else ""
        print(f"  {metric:25s}: {agg}{suffix}")
    else:
        print(f"  {metric:25s}: FAILED")
print()
# Out:
# ================================================================================
# RAGAS EVALUATION RESULTS - Health Wallet RAG
# ================================================================================
#
# Eval Data:    182 questions
# Timestamp:    20260509_193151
#
# AGGREGATED SCORES:
# ----------------------------------------
#   answer_similarity        : 0.9058946516482095
#   answer_correctness       : 0.7908284338860674

# %%
# Per-question breakdown
print("PER-QUESTION SCORES:")
print("-" * 80)
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', 200)
print(df.to_string(index=False))
# Out:
# PER-QUESTION SCORES:
# --------------------------------------------------------------------------------
#                                                                          question  answer_similarity  answer_correctness
#                                     Kde nájdem Peňaženku zdravia? Je spoplatnená?           0.956175            0.511771
#                          Prečo je Peňaženka zdravia viazaná na mobilnú aplikáciu?           0.992833            0.623208
# Na čerpanie príspevkov z Peňaženky zdravia musím mať mobilnú aplikáciu,\nalebo mi           0.995436            0.998859
# Ak som sa opäť vrátil do VšZP, môžem pre Peňaženku zdravia využívať svoje\nstaré            0.995281            0.811349
#       Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku\nzdravia?           0.667658            0.333540
# Aktualizácia mobilnej aplikácie prebehne automaticky, alebo si novú verziu\nmusím           1.000000            1.000000
# Máte kontakt na podporu pre klientov? Mám problémy s inštaláciou mobilnej\napliká           0.903632            0.825872
#  Prečo je potrebná aktivácia mobilnej aplikácie? Nie je to zbytočná strata\nčasu?           0.937146            0.779741
#               Ak mám nový telefón, musím si opätovne aktivovať mobilnú aplikáciu?           0.997684            0.749409
# Ak si nanovo zaktivujem aplikáciu, musím si opätovne vytvoriť aj skupinu v\nPeňaž           0.834281            0.958888
#                                           Budú sa finančné príspevky časom meniť?           0.565430            0.141109
# Prečo musím potvrdiť nejaké súhlasy, ak chcem čerpať príspevky z\nPeňaženky zdrav           0.994040            0.998509
# Na čo slúži e-mailová adresa? Je to povinný údaj? Budem dostávať z\nmobilnej apli           0.998732            0.999693
# Kde nájdem presný zoznam finančných príspevkov, ktoré môžem čerpať z\nPeňaženky z           0.913965            0.978465
# Môžem čerpať finančné príspevky z Peňaženky zdravia aj bez vytvárania\nskupiny, t           1.000000            1.000000
#                               Aký limit finančných prostriedkov mám k dispozícii?           0.967754            0.908598
#                      Kto môže čerpať finančné príspevky v Peňaženke zdravia MINI?           0.913062            0.574412
#          Mám pozvánku do skupiny. Môžem v tomto štádiu čerpať finančné príspevky?           0.993638            0.825339
#  Začal som vytvárať skupinu, sme zatiaľ 2 a neviem, kedy sa nám podarí vytvoriť s           0.979713            0.844922
#                 Môže finančné príspevky z Peňaženky zdravia MINI čerpať aj dieťa?           0.998985            0.999740
#  Aký je postup čerpania finančných príspevkov z Peňaženky zdravia MINI pre dieťa?           0.924350            0.731134
#  Môžem ako dospelý v Peňaženke zdravia MINI konať aj za dieťa, ktoré mi bolo zver           0.969571            0.992426
#  Môže požiadať o čerpanie finančných príspevkov z Peňaženky zdravia MINI aj osoba           0.989600            0.997383
#  Môžem požiadať o finančný príspevok ako fyzická osoba, ak som ako FO – podnikate           0.981233            0.888170
#  Po príchode zo zahraničia sa poistím vo VšZP. Môžem požiadať o finančný príspevo           0.981044            0.790722
#  Preplatíte mi žiadosť o finančný príspevok v prípade, že odídem do zahraničia a            0.811050            0.502696
#  Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís           0.757340            0.403680
#                                                Ako požiadam o finančný príspevok?           0.877745            0.484142
#                                                 Do akej doby musím podať žiadosť?           0.953816            0.738481
#                  Čo potrebujem k podaniu žiadosti? Kde a ako mám žiadosť vyplniť?           0.951259            0.806749
#                                    Sú obmedzenia pri podávaní prílohy k žiadosti?           0.864558            0.591268
#                                                 Ako zistím, kto je zmluvný lekár?           0.931111            0.875655
#  Môžem si podať žiadosť o finančný príspevok aj v prípade, že som navštívil súkro           0.977174            0.644264
#                              Musím mať absolvované všetky preventívne prehliadky?           0.969234            0.742258
#                Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára?           0.871316            0.780276
#                                         Čo keď mi lekár nedá za ošetrenie doklad?           0.829602            0.957531
#                               Ako si pozriem, koľko som už na príspevky vyčerpal?           0.849053            0.962333
#                               Ako si do Peňaženky zdravia MINI vložím číslo účtu?           1.000000            1.000000
#                                                          Môžem zmeniť číslo účtu?           0.748056            0.437298
#                                         Pošlete mi peniaze aj na zahraničný účet?           0.960407            0.615140
#                                                Kedy zasielate finančné príspevky?           0.981734            0.790911
#  Môžem podať žiadosť, aj keď žiadam o finančný príspevok v sume vyššej, ako je su           0.985147            0.846284
#                                  Prečo ste mi finančný príspevok ešte neuhradili?           0.913259            0.780961
#               Akou formou sa dozviem o stave mojej žiadosti o finančný príspevok?           0.898778            0.916991
#               Žiadosť ste mi ukončili bez úhrady, čo mám robiť? Ako zistím dôvod?           0.929489            0.932481
#                                        Môžem podať viac žiadostí na jeden doklad?           0.968198            0.542050
#                         Žiadosť ste mi ukončili bez úhrady. Môžem ju podať znova?           0.980394            0.995074
#           Budem musieť vrátiť príspevok, ak v nasledujúcom roku zmením poisťovňu?           0.869475            0.860100
#             Aké finančné príspevky na zuby môžem čerpať v Peňaženke zdravia MINI?           0.957077            0.700803
#        Kde nájdem zmluvných zubárov, u ktorých môžem absolvovať dentálnu hygienu?           0.651663            0.662855
#                         Na čo je určený finančný príspevok na zuby 1× 40 € ročne?           0.825407            0.506169
#                Na ktoré výkony dentálnej hygieny sa vzťahuje limit 1× 40 € ročne?           0.872742            0.968216
#  Môžem použiť príspevok 1× 30 € ročne na strojček pre dieťa z Peňaženky zdravia M           0.981246            0.888138
#          Finančné príspevky na lieky bude môcť čerpať dospelý poistenec aj dieťa?           0.890398            0.597513
#               Vzťahuje sa finančný príspevok na lieky aj na dietetické potraviny?           0.932429            0.608114
#  Ako je to s doplatkami za lieky zo zákona? Strhnú sa mi zo sumy príspevku v Peňa           0.977482            0.994385
#  Čerpanie finančného príspevku na lieky je maximálne vo výške 20 € na poistenca n           1.000000            1.000000
#  Preplatíte mi aj drahšie lieky? Ak si vyberiem v lekárni liek na predpis a uhrad           0.839209            0.876347
#  V lekárni mi namiešali masť alebo kvapky. Môžem v tomto prípade požiadať o finan           0.835675            0.851622
#  Má dieťa nárok na finančný príspevok z Peňaženky zdravia MINI v prípade, že abso           0.868873            0.967218
#             Môžem získať z Peňaženky zdravia MINI príspevok na kontaktné šošovky?           0.943143            0.985751
#     Môžem si prevziať okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP?           0.903504            0.975911
#    Je nejaké obmedzenie výšky dioptrie na príspevok okuliarový rám pre dospelých?           0.864100            0.816079
#  Aké podmienky musím splniť, aby som dostal príspevok na okuliarový rám pre dospe           0.809884            0.779533
#  Príspevok pre deti 100 € platí samostatne na okuliarový rám a aj na okuliarové š           0.961815            0.990497
#     Je členstvo v športovom klube podmienkou na príspevok na športovú prehliadku?           0.683598            0.503949
#  Je možné čerpať finančný príspevok aj pri preočkovaní, napríklad pri kliešťovej            0.756970            0.522576
#  Preplatíte každú dávku očkovania alebo musím mať všetky odporúčané vakcíny podľa           0.986882            0.996713
#  Na aké špeciálne samotesty si môžem finančný príspevok uplatniť a do akej výšky?           0.956102            0.895260
#                       Môžem požiadať o preplatenie očkovania proti ovčím kiahňam?           0.923356            0.980794
#                                                     Ako si požičať monitor dychu?           0.832905            0.508290
#  Aká je maximálna výška príspevku, ktorú môže žena získať na moderné cytologické            0.939573            0.797434
#                        Ako môžem začať používať skupinovú Peňaženku zdravia MAXI?           0.779204            0.382410
#                        Dokedy si môžem vytvoriť skupinu v Peňaženke zdravia MAXI?           0.788342            0.197114
#                                                    Kto je správca? Čo bude robiť?           0.945189            0.664958
#                                                           Ako sa stanem správcom?           0.960995            0.940205
#                                   Ako pridám člena? Aké údaje o ňom musím vedieť?           0.926004            0.937351
#                                         Pridá sa mi dieťa do skupiny automaticky?           0.980269            0.673616
#                                                             Ako sa stanem členom?           0.944667            0.986192
#                                       Ako uvidím, že ma niekto pozval do skupiny?           0.964171            0.907720
#  Keď si pridám do Peňaženky zdravia MAXI člena, ktorý nemá nainštalovanú mobilnú            0.913910            0.978446
#                       Ako sa správca dozvie, že som potvrdil prijatie do skupiny?           0.816019            0.703924
#  Chcem niekoho pridať, ale ukazuje mi, že už je v inej skupine. Ako si ho pridám?           0.966923            0.777483
#  Môžem si pridať do skupiny v Peňaženke zdravia MAXI okrem rodiny a príbuzných aj           0.872348            0.817927
#         Peňaženka zdravia MAXI je založená na princípe solidarity. Čo to znamená?           0.906295            0.601765
#  Čo so staršími ľuďmi, ktorí nemajú mobil? Ako môžu využiť finančné príspevky z P           0.878761            0.936900
#                                     Je Peňaženka zdravia MAXI iba pre poistencov?           0.776699            0.194155
#  Keď chcem pridať do svojej skupiny osobu pozbavenú spôsobilosti na právne úkony,           0.973383            0.993355
#                            V roku 2024 som bol v skupine. Prečo ju teraz nevidím?           0.970960            0.992702
#  Ak som už členom/správcom aktívnej skupiny, bude táto skupina pokračovať aj v na           0.872744            0.627200
#  Kde nájdem presný zoznam poskytovaných finančných príspevkov v rámci Peňaženky z           0.854144            0.642103
#       Kedy môže skupina začať čerpať finančný príspevok z Peňaženky zdravia MAXI?           0.835341            0.423181
#  Akým spôsobom je možné zdieľať 50 % sumy medzi členmi v skupine? Je potrebné na            1.000000            1.000000
#                     Má na to právo len správca skupiny alebo kto o tom rozhoduje?           1.000000            1.000000
#                    Zdieľanú sumu je možné využiť na akýkoľvek finančný príspevok?           0.846202            0.961455
#  V prípade, že člen už určitú časť svojej sumy minul a má k dispozícii napríklad            0.814685            0.703700
#  Môže si moje neplnoleté dieťa pridať do skupiny niekto iný, keď mu to odsúhlasím           0.750987            0.596846
#  Môžem sa stať členom Peňaženky zdravia MAXI ako fyzická osoba, ak som ako FO – p           0.882036            0.970584
#                                                           Môžem odísť zo skupiny?           0.947012            0.813660
#                                          Môže správca niekoho vyradiť zo skupiny?           0.934487            0.533540
#  Čo ak prídem zo zahraničia a poistím sa vo VšZP? Môžem sa pripojiť do skupiny? D           0.956432            0.801696
#  Čo keď odídem do zahraničia a ukončím poistenie vo VšZP? Dostanem finančný prísp           0.779020            0.569927
#          Čo ak správca prestane byť poistencom, zomrie alebo odíde do zahraničia?           0.968028            0.710774
#     Čo ak sme 3 členovia s nárokom v skupine a niekto odíde do zahraničia/zomrie?           0.961688            0.740402
#                                    Ako požiadam o čerpanie finančných príspevkov?           0.918986            0.570707
#  Som správca, musím podať žiadosť o finančný príspevok za každého člena individuá           0.971914            0.992971
#                                        Je nejaký čas, dokedy musím žiadosť podať?           0.731849            0.611692
#                  Čo potrebujem k podaniu žiadosti? Kde a ako mám žiadosť vyplniť?           0.852531            0.566152
#                             Sú nejaké obmedzenia pri podávaní prílohy k žiadosti?           0.786249            0.625238
#                                               Prečo si nemôžem podať žiadosť sám?           0.942096            0.835450
#                                                 Ako zistím, kto je zmluvný lekár?           0.934799            0.876487
#  Môžem si dať preplatiť doklad o úhrade aj od súkromného lekára alebo zariadenia?           0.928058            0.808893
#    Som správcom skupiny. Ako si pozriem, kto a koľko si už na príspevky vyčerpal?           0.907930            0.976988
#                         Kde uvidím, koľko si dali preplatiť iní členovia skupiny?           0.991501            0.676450
#                              Musím mať absolvované všetky preventívne prehliadky?           0.971890            0.899223
#  Som správca skupiny a podávam žiadosť za člena. Musíme mať všetci absolvované pr           0.960392            0.540051
#                Čo ak mám absolvovanú preventívnu prehliadku u nezmluvného lekára?           0.831872            0.617079
#                          Musia mať všetci v našej skupine preventívne prehliadky?           0.892036            0.673032
#                                            Máme v skupine dlžníka. Čo máme robiť?           0.967137            0.787212
#                                         Čo keď mi lekár nedá za ošetrenie doklad?           0.858670            0.964668
#                                                        Na aký účet prídu peniaze?           0.868342            0.667101
#                               Ako si do Peňaženky zdravia MAXI vložím číslo účtu?           0.971748            0.992964
#                                                          Môžem zmeniť číslo účtu?           0.787691            0.625489
#                                         Pošlete mi peniaze aj na zahraničný účet?           0.946400            0.986600
#                                              Kedy mi uhradíte finančný príspevok?           0.969694            0.992424
#       Môžem podať žiadosť, aj keď žiadam viac, ako je výška sumy v našej skupine?           0.852891            0.813216
#  Môžem podať žiadosť, aj keď žiadam o finančný príspevok v sume vyššej, ako je su           0.985136            0.674855
#                                  Prečo ste mi finančný príspevok ešte neuhradili?           0.908311            0.883289
#               Akou formou sa dozviem o stave mojej žiadosti o finančný príspevok?           0.903725            0.675931
#               Žiadosť ste mi ukončili bez úhrady, čo mám robiť? Ako zistím dôvod?           0.932317            0.586151
#                                        Môžem podať viac žiadostí na jeden doklad?           1.000000            1.000000
#                         Žiadosť ste mi ukončili bez úhrady. Môžem ju podať znova?           0.977735            0.844434
#  Budem musieť vrátiť finančný príspevok, ak v nasledujúcom roku zmením poisťovňu?           0.842119            0.810530
#             Aké finančné príspevky na zuby môžem čerpať v Peňaženke zdravia MAXI?           0.927144            0.693422
#        Kde nájdem zmluvných zubárov, u ktorých môžem absolvovať dentálnu hygienu?           0.651418            0.912855
#                           Na čo je určený finančný príspevok na zuby 2× 40 ročne?           0.852665            0.485993
#                Na ktoré výkony dentálnej hygieny sa vzťahuje limit 2× 40 € ročne?           0.874213            0.718553
#        Môžem požiadať o príspevok na strojček pre dieťa z Peňaženky zdravia MAXI?           0.938783            0.708381
#                     Sú v limite 450 € na strojček pre dieťa zahrnuté aj kontroly?           0.676901            0.919225
#  Je možné u dieťaťa čerpať benefit z Peňaženky zdravia MAXI na strojček, ak je vý           0.996278            0.999087
#  Ak je suma na doklade za dentálnu hygienu vyššia ako 40 €, môžem ju rozdeliť do            0.726225            0.181536
#  Finančné príspevky vo výške 200 € na lieky, dietetické potraviny budú môcť čerpa           0.975251            0.806319
#  Majú nárok na finančný príspevok na lieky v Peňaženke zdravia MAXI aj dospelí, k           0.871685            0.884760
#  Ako je to s doplatkami za lieky zo zákona? Strhnú sa mi zo sumy príspevku v Peňa           0.994017            0.748492
#  Čerpanie finančného príspevku na lieky a dietetické potraviny pre deti a ich zák           0.893705            0.673430
#  Preplatíte mi aj drahšie lieky? Ak si vyberiem v lekárni liek na predpis a uhrad           0.807182            0.826984
#  Môžem čerpať finančný príspevok na lieky a dietetické potraviny ako zákonný zást           0.977018            0.994256
#  V lekárni mi namiešali masť alebo kvapky, môžem pri nich požiadať o finančný prí           0.883842            0.971086
#  Má dieťa nárok na príspevok z Peňaženky zdravia MAXI v prípade, že absolvovalo v           0.901534            0.600425
#             Môžem získať z Peňaženky zdravia MAXI príspevok na kontaktné šošovky?           0.980258            0.995028
#      Môžem si zakúpiť okuliare aj v optike, ktorá nie je zmluvným partnerom VšZP?           0.910036            0.977598
#  Vzťahuje sa príspevok do výšky 450 € na laserovú operáciu excimerovým alebo femt           0.996743            0.999172
#  Vzťahuje sa príspevok do výšky 450 € na laserovú operáciu excimerovým alebo femt           0.996688            0.999172
#               Je možné absolvovať laserovú operáciu očí aj na nezmluvnej klinike?           0.943367            0.735869
#  Mám sivý zákal oka. Je možné príspevok na laserovú operáciu použiť aj na tento ú           1.000000            0.750000
#  Mám dcéru, ktorá má 16 rokov. Je možné použiť príspevok na laserovú operáciu aj            0.992466            0.998094
#  Prečo ste stanovili podmienku na absolvovanie laserovej operácie očí od výšky di           0.980814            0.995192
#  Je možné získať príspevok do maximálnej výšky 450 € aj na operáciu dioptrickej v           0.971112            0.742803
#    Je nejaké obmedzenie výšky dioptrie na príspevok okuliarový rám pre dospelých?           0.979040            0.844760
#  Aké podmienky musím splniť, aby som príspevok na okuliarový rám pre dospelých do           0.777199            0.694223
#  Príspevok pre deti 100 € platí samostatne na okuliarový rám a aj na okuliarové š           0.955128            0.988782
#     Je členstvo v športovom klube podmienkou na príspevok na športovú prehliadku?           0.708227            0.510390
#  Dá sa finančný príspevok uplatniť aj pri preočkovaní, napríklad pri kliešťovej e           0.779874            0.444968
#  Preplatíte každú dávku očkovania alebo musím mať všetky odporúčané vakcíny podľa           0.965944            0.991486
#  Kto si môže uplatniť finančný príspevok z Peňaženky zdravia na očkovanie proti v           0.970789            0.992695
#  Na aké špeciálne samotesty si môžem finančný príspevok uplatniť a do akej výšky?           0.956049            0.895262
#                       Môžem požiadať o preplatenie očkovania proti ovčím kiahňam?           0.923176            0.980794
#                                                     Ako si požičať monitor dychu?           0.822974            0.505744
#  Do akej maximálnej výšky a na aké typy testov si môžem uplatniť finančný príspev           0.978412            0.994581
#  Môže získať finančný príspevok na prenatálne testovanie aj žena vo veku 30 rokov           0.919988            0.605004
#  Aká je maximálna výška finančného príspevku, ktorú môže žena získať na moderné c           0.977964            0.994474
#  Je potrebný predchádzajúci súhlas poisťovne na získanie finančného príspevku na            0.978772            0.807220
#  Je potrebný predchádzajúci súhlas poisťovne na získanie príspevku na 4.cyklus as           0.848782            0.854943
#  Dá sa získať finančný príspevok aj na 4. cyklus asistovanej reprodukcie IVF mimo           0.854101            0.963635
#  Má nárok na získanie finančný príspevku na 4.cyklus asistovanej reprodukcie IVF            0.951951            0.838045
#  Je možné v rámci finančného príspevku 100 €/ročne na doplatky za glukózové senzo           0.995008            0.998721
#  Prečo je stanovená podmienka uplatnenia finančného príspevku na glukózové senzor           0.966991            0.991759
#  Je možné získať finančný príspevok aj na doplatky za glukózové senzory pre dieťa           0.771905            0.943021
#                              Pre akú skupinu diabetikov platí finančný príspevok?           1.000000            0.875000
#     Za akých podmienok môžem zmeniť Peňaženku zdravia MINI na MAXI alebo\nnaopak?           0.945917            0.986562
#     Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho\nroka?           0.441421            0.860495
#  Čo sa stane s mojimi finančnými prostriedkami, ktoré som čerpal pred zmenou typu           0.999439            0.849859

# %%
# Identify weak spots
print("\nDIAGNOSTICS:")
print("=" * 60)

for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[df[metric].notna()]
    skipped = len(df) - len(valid)
    if skipped > 0:
        print(f"\n{metric}: {skipped}/{len(df)} entries skipped (parsing failure)")

    low_scores = valid[valid[metric] < 0.5]
    if len(low_scores) > 0:
        print(f"\n{metric} < 0.5 ({len(low_scores)} questions):")
        for _, row in low_scores.iterrows():
            print(f"  - {row['question']} (score: {row[metric]:.3f})")

# Summary interpretation
print("\n" + "=" * 60)
print("INTERPRETATION:")
for metric in SCORING_FUNCTIONS:
    if metric not in df.columns:
        continue
    valid = df[metric].dropna()
    if len(valid) == 0:
        print(f"  {metric:25s}: NO DATA")
        continue
    avg = valid.mean()
    if avg >= 0.8:
        verdict = "GOOD"
    elif avg >= 0.5:
        verdict = "NEEDS IMPROVEMENT"
    else:
        verdict = "POOR"
    print(f"  {metric:25s}: {avg:.3f} - {verdict}")
# Out:
# DIAGNOSTICS:
# ============================================================
#
# answer_similarity < 0.5 (1 questions):
#   - Ako často môžem meniť Peňaženku zdravia MINI a MAXI počas kalendárneho
# roka? (score: 0.441)
#
# answer_correctness < 0.5 (12 questions):
#   - Som váš dlhoročný poistenec, prečo aj ja nemám nárok na Peňaženku
# zdravia? (score: 0.334)
#   - Budú sa finančné príspevky časom meniť? (score: 0.141)
#   - Dostal som pozvánku do skupiny, môžem v tomto štádiu čerpať nejaké finančné prís (score: 0.404)
#   - Ako požiadam o finančný príspevok? (score: 0.484)
#   - Môžem zmeniť číslo účtu? (score: 0.437)
#   - Ako môžem začať používať skupinovú Peňaženku zdravia MAXI? (score: 0.382)
#   - Dokedy si môžem vytvoriť skupinu v Peňaženke zdravia MAXI? (score: 0.197)
#   - Je Peňaženka zdravia MAXI iba pre poistencov? (score: 0.194)
#   - Kedy môže skupina začať čerpať finančný príspevok z Peňaženky zdravia MAXI? (score: 0.423)
#   - Na čo je určený finančný príspevok na zuby 2× 40 ročne? (score: 0.486)
#   - Ak je suma na doklade za dentálnu hygienu vyššia ako 40 €, môžem ju rozdeliť do  (score: 0.182)
#   - Dá sa finančný príspevok uplatniť aj pri preočkovaní, napríklad pri kliešťovej e (score: 0.445)
#
# ============================================================
# INTERPRETATION:
#   answer_similarity        : 0.906 - GOOD
#   answer_correctness       : 0.791 - NEEDS IMPROVEMENT

# %% [markdown]
# ## Save Results
#
# Save experiment config and metric results to `results/` for cross-experiment comparison.

# %%
import os

os.makedirs("results", exist_ok=True)

# --- Experiment config ---
experiment_config = {
    "experiment_id": "experiment4",
    "description": " Gemma-4-31b-it",
    "timestamp": datetime.now().isoformat(),
    "eval_model": ragas_llm_model,
    "num_questions": len(eval_data),
}

with open("results/experiment_config.json", "w", encoding="utf-8") as f:
    json.dump(experiment_config, f, ensure_ascii=False, indent=2)
print("Saved results/experiment_config.json")

# --- Save each metric ---
for metric_name in SCORING_FUNCTIONS:
    m_result = {"metric": metric_name, "aggregated": None, "num_scored": 0, "num_skipped": 0, "per_question": []}
    if metric_name in all_scores:
        sr = all_scores[metric_name]
        m_result["aggregated"] = compute_aggregated(sr)
        for i, gen in enumerate(ref_results.generations):
            score = sr.score_rows[i].get("score", None) if i < len(sr.score_rows) else None
            is_valid = score is not None and str(score) != "nan"
            if is_valid:
                m_result["num_scored"] += 1
            else:
                m_result["num_skipped"] += 1
            entry = {"question": gen["user_input"], "score": round(float(score), 4) if is_valid else None}
            entry["response"] = eval_data[i]["response"] if i < len(eval_data) else ""
            entry["reference"] = eval_data[i]["reference"] if i < len(eval_data) else ""
            m_result["per_question"].append(entry)

    filename = f"results/{metric_name}.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(m_result, f, ensure_ascii=False, indent=2)
    print(f"Saved {filename} (mean={m_result['aggregated']}, scored={m_result['num_scored']}, skipped={m_result['num_skipped']})")

print("\nAll results saved to results/ directory.")
# Out:
# Saved results/experiment_config.json
# Saved results/answer_similarity.json (mean=0.9058946516482095, scored=182, skipped=0)
# Saved results/answer_correctness.json (mean=0.7908284338860674, scored=182, skipped=0)
#
# All results saved to results/ directory.
